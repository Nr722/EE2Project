# %% [markdown]
# <a href="https://colab.research.google.com/github/Nr722/EE2Project/blob/main/02_CNN_Introduction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction to Convolutional Neural Networks
#
# This tutorial addresses the basic concepts regarding Convolutional Neural Networks and their implementation using the Keras framework.
# Convolutional Neural Networks (CNNs) are a class of feed-forward artificial neural architecture. They are applied to analyse visual 2D imagery, meaning that we can feed images directly into a CNN without the need to flatten them into a 1D vector as done in the previous tutorial.
# CNNs have revolutionised the field of computer vision in the last decade. In 2012 Alex Krizhevsky introduced the AlexNet architecture to win the ImageNet Challenge (one of the most important competitions on image classification within the Computer Vision community), by reducing the top-5 error more than 10 percentage points, which was an incredible improvement at that time. As of now, CNNs are used not only on image classification but in many other computer vision tasks.
#
# ![](https://cdn-5f733ed3c1ac190fbc56ef88.closte.com/wp-content/uploads/2017/03/alexnet_small-1.png)
#
# The image above is from [cv-tricks' blog](https://cv-tricks.com/cnn/understand-resnet-alexnet-vgg-inception/) and shows the proposed AlexNet architecture. It is composed of 5 convolutional layers followed by 3 fully connected layers. Nowadays, we can find much deeper and more complex architectures, which outperform AlexNet on the ImageNet Challenge.

# %% [markdown]
# ## CNN Structure
#
# The basic pipeline of common CNNs consists of an image as input and a stack of convolutional layers that extract a feature representation from the input image. The final shape of the image representation is conditioned on the type of problem/task that the architecture is facing. For instance, the output of the last layer in a classification problem is a probability vector. Each dimension of the probability vector represents how likely is that the input image belongs to a specific class. However, the architecture design is up to us, and therefore, we could code a network that outputs a single value for regression problems, or that generates a new image map for semantic segmentation. Now, let's dig in a bit into CNN and introduce some layers that are widely used.

# %% [markdown]
# ### 2D Convolutional Layer
#
# The most common layer in any CNN architecture is the 2D convolutional layer. Convolutional layers are specifically designed to extract features from images or even extract features from previously extracted features. As shown in the following illustration, 2D convolutions apply the same filter to the full image. And therefore, due to its nature, 2D convolutional filters exploit the local information presented in images, making them a powerful tool for image analysis.
#
# ![](https://cdn-images-1.medium.com/max/800/1*Fw-ehcNBR9byHtho-Rxbtw.gif)
#
# Image [source](https://towardsdatascience.com/intuitively-understanding-convolutions-for-deep-learning-1f6f42faee1).
#
# The latest deep learning frameworks have made possible the integration of convolutional layers easily on our architectures with only a single line of code. We will address here how 2D convolutions work since full understanding is needed to comprehend how any CNN operates. The following images and some explanations can be further explored on the original [Irhum Shafkat's blog](https://towardsdatascience.com/intuitively-understanding-convolutions-for-deep-learning-1f6f42faee1) or in the [Neural Networks and Deep Learning](http://neuralnetworksanddeeplearning.com/) book. Both are strongly recommended.
#
# To understand 2D convolutions, we need to define first what a kernel is. Kernels are simply matrices of numbers. The numbers on the kernels are the so-called weights, and the weights on the kernels change as we train the network. Hence, network training aims to optimise the network's parameters (update the kernel weights) such that the cost function is minimised.
#
# The 2D convolution operation takes the network's kernels and "slides" them over the input image (alike to a sliding window) as in the following image from [PyImageSearch](https://www.pyimagesearch.com/2015/03/23/sliding-windows-for-object-detection-with-python-and-opencv/) blog:
#
# ![](https://pyimagesearch.com/wp-content/uploads/2014/10/sliding_window_example.gif)
#
# In each step, the network performs an element-wise multiplication with the elements that are currently on. The results of this elementwise multiplication are added to obtain the output value of the operation. CNNs repeat previous step for all the positions of the sliding window, composing at the end the feature map. This generated feature map can go through another 2D convolutional layer and create more powerful features.
#
# >
#
# ![](https://cdn-images-1.medium.com/max/800/1*Zx-ZMLKab7VOCQTxdZ1OAw.gif)
#
# >
# The previous image shows the 2D convolution operation. Thus, the new feature values are the weighted sum of all the elements in the sliding window after the elementwise multiplication between input and kernel.  The bigger the size of the kernel is, the more feature elements contribute to the final output value. In contrast to fully connected layers, where a new feature value is a weighted sum over **all** input values, as mentioned, 2D convolutions compute features based on local areas. In other words, instead of looking at every input component, they consider only features coming from close locations.
#
# In the above example, the input image on the left has a size of 5x5 and the dimension of the resulting feature map is 3x3, showing that the size of the output maps is not always equal to the input. Hence, the output size can be computed by doing:
#
# $O = W - K + 1$,
#
# where $O$ is the output height/length, $W$ is the input height/length and $K$ is the kernel size. The output size is not only conditioned on the input size but also on the kernel size. Check in the following code cell how the output feature map shape changes as you increase the kernel size. In Keras, we define the layer by using `Conv2D` from `keras.layers` (documentation [here](https://keras.io/layers/convolutional/#conv2d)).

# %%
import numpy as np
import keras
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Conv2D

# Generate dummy data
input_feature = np.random.random((1, 100, 100, 1))

# input: 100x100 image with 1 channels -> (100, 100, 1) tensor.
# this applies 1 convolution filter of size 3x3 each.
model = Sequential()
model.add(Conv2D(1, (3, 3), input_shape=(100, 100, 1)))

output_feature = model.predict(input_feature)

print('Input size: ({:}, {:})'.format(input_feature.shape[1], input_feature.shape[2]))
print('Output size: ({:}, {:})'.format(output_feature.shape[1], output_feature.shape[2]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# Input size: (100, 100)
# Output size: (98, 97)

# %% [markdown]
# Moreover, the kernel size and the input size are not the only parameters affecting the output size. We are going to introduce two extra elements that change the size of the output map: the padding and the stride.

# %% [markdown]
# ### Adding Padding to Input Features
#
# In some tasks, such as [image translation](https://arxiv.org/pdf/1611.07004.pdf), we need the output size to be equal to the input size. The solution to that is using padding, where extra edges are added to the input features so that the dimension is not reduced after the convolutional layer. Normally those pixels have $0$ value (termed zero-padding), but depending on the application other methods could be used, e.g., reflection or symmetric padding.
#
# ![](https://cdn-images-1.medium.com/max/800/1*1okwhewf5KCtIPaFib4XaA.gif)
#
# If padding is used, the new output size can be computed by doing:
#
# $O = W - K + 2P+ 1$,
#
# where $P$ is the padding value. $P$ must be set in concordance with the kernel size if dimensionality wants to be preserved. Padding can be added to the `Conv2d` layer in Keras by using the padding argument and selecting one of the two settings: `valid`, which is the default value and means no padding; and `same`, which adapts the padding value to have the same output size as input size.

# %%
import numpy as np
import keras
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Conv2D

# Generate dummy data
input_feature = np.random.random((1, 100, 100, 1))

# input: 100x100 image with 1 channels -> (100, 100, 1) tensor.
# this applies 1 convolution filter of size 3x3 each.
# attribute padding='same' applies zero-padding to the input feature map
model = Sequential()
model.add(Conv2D(1, (3, 3), input_shape=(100, 100, 1), padding='same'))

output_feature = model.predict(input_feature)

print('Input size: ({:}, {:})'.format(input_feature.shape[1], input_feature.shape[2]))
print('Output size: ({:}, {:})'.format(output_feature.shape[1], output_feature.shape[2]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# Input size: (100, 100)
# Output size: (100, 100)

# %% [markdown]
# ### Using Stride in Convolutional Layers
#
# The stride operation allows the convolutional layers to skip some of the sliding windows explained above. Hence, instead of jumping one pixel apart, we can define the number of skipped elements before computing the weighting sum between the kernel's weights and input features. A stride of 1 means that features will be extracted from all windows a pixel apart, so basically, every single window is computed. A stride of 2 means that we are selecting windows 2 pixels apart, skipping every other window in the process. Strides reduce the number of computations and consequently the size of the output map. In practice, as we go deeper into the CNN, the spatial size of the feature map gets smaller while the number of channels increases. Moreover, we can further reduce the size of the feature map using pooling operations, which we introduce later in this tutorial.
#
# ![](https://cdn-images-1.medium.com/max/800/1*BMngs93_rm2_BpJFH2mS0Q.gif)
#
# If strides are used, the new output size can be computed as:
#
# $O = \dfrac{W - K + 2P}{S}+ 1$,
#
# where $S$ is the stride value. The stride is set in the layer by using the `strides` argument.

# %%
import numpy as np
import keras
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Conv2D

# Generate dummy data
input_feature = np.random.random((1, 100, 100, 1))

# input: 100x100 image with 1 channels -> (100, 100, 1) tensor.
# this applies 1 convolution filter of size 3x3 each.
# attribute padding='same' applies zero-padding to the input feature map
# attribute strides=2 applies applies stride of 2
model = Sequential()
model.add(Conv2D(1, (3, 3), input_shape=(100, 100, 1), padding='same', strides=2))

output_feature = model.predict(input_feature)

print('Input size: ({:}, {:})'.format(input_feature.shape[1], input_feature.shape[2]))
print('Output size: ({:}, {:})'.format(output_feature.shape[1], output_feature.shape[2]))
# Out:
# Input size: (100, 100)
# Output size: (50, 50)

# %% [markdown]
# ## Differences Between Kernel and Filters
#
# The examples above take as input a single-channel image and compute a feature map with also one channel. However, when dealing with RGB images or feature maps, the input is no longer a single-channel map but, instead, they can have multiple channels. In the case of an RGB image, for each 2D convolution, we will need to define 3 kernels to interact with each of the image's channel colours. This group of kernels is called a filter. Thus, a filter is a collection of kernels that produces a single output.
#
# As a regular practice when defining Deep Learning models, we increase the number of filters in each convolutional layer as we go deeper into the model. Due to the element-wise multiplication, the number of kernels on each filter must be the same that the number of channels in the input feature map. Keras already deals with the number of kernels inside each filter. Keras keeps track of the input size in each convolutional layer unlike other frameworks (Pytorch or TensorFlow). Hence, in Keras, we must only decide the number of filters (output channels) in each layer.
#
# The next figure shows how the convolution is performed when having three input channels. First, one filter uses its three independent kernels to convolve with the RGB channels of the input image:
#
# ![](https://cdn-images-1.medium.com/max/1000/1*8dx6nxpUh2JqvYWPadTwMQ.gif)
#
# Next, each of the processed feature maps is added together to obtain a single channel:
#
# ![](https://cdn-images-1.medium.com/max/1000/1*CYB2dyR3EhFs1xNLK8ewiA.gif)
#
# Finally, we add the bias term to obtain the feature map. There is a single bias for the full output channel map. This operation is repeated for all the filters inside the convolutional layer.
#
# Now, we show how to use a `Conv2D` layer that takes an input image with 3 channels and generates an output map with 32 channels.

# %%
import numpy as np
import keras
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Conv2D

# Generate dummy data
input_feature = np.random.random((1, 100, 100, 3))

# input: 100x100 image with 3 channels -> (100, 100, 3) tensor.
# this applies 32 convolution filters of size 3x3 each.
# attribute padding='same' applies zero-padding to the input feature map
# attribute strides=2 applies applies stride of 2
model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=(100, 100, 3), padding='same', strides=2))

output_feature = model.predict(input_feature)

print('Input size: ({:}, {:}, {:})'.format(input_feature.shape[1], input_feature.shape[2], input_feature.shape[3]))
print('Output size: ({:}, {:}, {:})'.format(output_feature.shape[1], output_feature.shape[2], output_feature.shape[3]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# Input size: (100, 100, 3)
# Output size: (50, 50, 30)

# %% [markdown]
# ## Activation Functions
#
# As seen in previous tutorials, after a `Dense` layer we usually can find an activation function. We introduce here how to use them after `Conv2D` layers. Those activation functions are a set of operators that maps the feature values to a new set of values, the mapping depends on the function at hand. The main reason for using activation functions is that they add non-linearities to the network, giving more expressive power to the network, which will be able to reproduce more complex functions.
#
#
# The complete list of activation functions that Keras offers can be found [here](https://keras.io/activations/). We introduce here some of them:
#
# *  **Sigmoid Function** sets the output in the range (0, 1). The sigmoid function is widely used in binary classification problems since its output can be taken as a probability value. `keras.activations.sigmoid(x)`:
#
# >![](https://i.ibb.co/Ph8dsTv/sigmoid.png)
#
# *  **Tanh Function** is a logistic function as sigmoid, but the range of the tanh function is (-1, 1). Contrary to sigmoid function, where the values close to 0 are set around 0.5, in the tanh function they will be still mapped around the 0 value. `keras.activations.tanh(x)`:
#
# >![](https://i.ibb.co/68g7LpL/tanh.png)
#
# *  **ReLU Function** is the most common activation function you can find in any current CNN as in general works better than the rest. The range of this function is in \[0, inf). It sets all negative values to 0 and hence is computationally easy to implement. As a drawback, during training some neurons *die*, meaning that the output is 0 for all available data points and no gradient is propagated there. `keras.activations.relu(x, alpha=0.0, max_value=None, threshold=0.0)`:
#
# >![](https://i.ibb.co/Zd9H8Z4/relu.png)
#
# *  **LeakyReLU Function** is a modified version of the ReLU activation above, which attempts to solve the problem of dying neurons that ReLU has. While ReLU does not backpropagate negative values, Leaky ReLU smooths those values without setting them to 0. That allows the gradients to backpropagate through the network even for negative values. `keras.layers.LeakyReLU(alpha=0.3)`:
#
# >![](https://i.ibb.co/dmnJ6h1/leakyrelu.png)
#
# *  **Softmax Function** is another widely activation function for multi-class classification problems and usually is employed as the last activation function in the classification model. This function sets all of the output elements to the range (0, 1). However, the softmax function does not take independently the input values to map it into its probability value. Softmax Function takes an un-normalized vector, $s$, and normalizes it into a probability distribution, $p$, following the softmax expression. As the output is a probability, the output elements add up to 1. `keras.activations.softmax(x, axis=-1)`. Thus, the output value $p_i$ is computed as:
#
# > $p_{i} = \dfrac{e^{s_i}}{\sum_{\substack{j}}^{N} e^{s_j}}$

# %% [markdown]
# The following example shows the feature maps before and after of the ReLU activation function. All values that are negative are set to 0 after the activation function.

# %%
import numpy as np
import keras
import tensorflow as tf
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
from keras.models import Sequential, Model
from keras.layers import Conv2D, Activation

# Generate dummy data
input_feature = np.random.random((1, 3, 3, 1)) - 0.5

# input: 3x3 image with 1 channel -> (3, 3, 1) tensor.
# This applies a 1 convolution filter of size 3x3 each.
# This applies a ReLU activation function
model = Sequential()
model.add(Conv2D(1, (3, 3), input_shape=(3, 3, 1), padding='same', strides=1, name='conv'))
model.add(Activation('relu'))

model_before_ReLU = Model(inputs=model.input, outputs=model.get_layer('conv').output)

output_feature = model_before_ReLU.predict(input_feature)
output_ReLu_feature = model.predict(input_feature)

print('Output Network without activation function')
print(output_feature)

print('')
print('Output Network after ReLU activation function')
print(output_ReLu_feature)
# Out:
# Output Network without activation function
# [[[[ 0.23390736]
#    [ 0.2609628 ]
#    [-0.10049579]]
#
#   [[ 0.47150436]
#    [ 0.01826818]
#    [-0.0576808 ]]
#
#   [[ 0.08542764]
#    [ 0.02355585]
#    [ 0.09083541]]]]
#
# Output Network after ReLU activation function
# [[[[0.23390736]
#    [0.2609628 ]
#    [0.        ]]
#
#   [[0.47150436]
#    [0.01826818]
#    [0.        ]]
#
#   [[0.08542764]
#    [0.02355585]
#    [0.09083541]]]]

# %% [markdown]
# ## Pooling Layer
#
# It is a common practice to insert a pooling layer between convolutional layers in CNNs. In a standard CNN architecture, we set the feature sizes to become smaller progressively to reduce the computation in the networks, and to merge the information from different spatial locations. To reduce the feature map sizes, we can either use bigger stride size in the convolutional layers or we can use pooling layers. Pooling layers perform a spatial sliding window and apply an operation to reduce the spatial size. Those operations vary depending on the architecture, being the max, mean and min pooling the most typical ones. Here, we will explain the max pooling, although all the others work similarly. Max pooling keeps only the max value in a neighbourhood, where the neighbourhood is defined by the size of the kernel. Let's visualise it, the next example shows the result of a Max Pooling layer with a 2x2 kernel and a stride of 2.
#
# ![](https://i.ibb.co/Xp454S4/MaxPool.png)
#
# As in convolutional layers, the final size is conditioned to the stride size of the pooling layer. However, contrary to convolutional layers, pooling layers operate independently on each of the input channels, without modifying the depth of the feature maps. To add max pooling to our model we need to import `MaxPooling2d` from `keras.layers` and define the stride and pooling size.

# %%
import numpy as np
import keras
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Conv2D, Activation, MaxPooling2D

# Generate dummy data
input_feature = np.random.random((1, 100, 100, 3))

# input: 100x100 image with 3 channels -> (100, 100, 3) tensor.
# this applies 32 convolution filters of size 3x3 each.
# attribute padding='same' applies zero-padding to the input feature map
# attribute strides=1 applies applies stride of 1
model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=(100, 100, 3), padding='same', strides=1))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding='same'))

output_feature = model.predict(input_feature)

print('Input size: ({:}, {:}, {:})'.format(input_feature.shape[1], input_feature.shape[2], input_feature.shape[3]))
print('Output size: ({:}, {:}, {:})'.format(output_feature.shape[1], output_feature.shape[2], output_feature.shape[3]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step
# Input size: (100, 100, 3)
# Output size: (50, 50, 32)

# %% [markdown]
# # Example: Classification on MNIST
#
# As opposed to the *Introduction to Keras* tutorial, in this section, we show how to perform image classification when the input data is a 2D image instead of a flat 1D vector.
#
# As discussed above, Convolutional Neural Networks aim to extract and exploit the local relationships on 2D maps, hence, CNNs are much more convenient for images than Multi-layer Perceptron models.
#
# First of all, we load the MNIST dataset from Keras' framework. The definition of the data is almost identical than in the Keras tutorial, although this time we are not reshaping the input images into a 1D vector.

# %%
import tensorflow as tf
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, BatchNormalization
from keras.utils import np_utils
from keras.datasets import mnist
from keras.optimizers import RMSprop
from keras.layers import Conv2D, MaxPooling2D, Flatten
import numpy as np

# the data, shuffled and split between train and test sets
# Here we are using the official test set as our validation set, in further
# tutorials, test and validation splits will be explained properly.
# Hence, even though the variables are `x_test` and `y_test`, they represent our validation set
(x_train, y_train), (x_test, y_test) = mnist.load_data()

shape = x_train.shape

# Normalize and reshape the input images
x_train = np.expand_dims(x_train.astype('float32'), -1)
x_test = np.expand_dims(x_test.astype('float32'), -1)

x_train /= 255
x_test /= 255

y_train_class = np_utils.to_categorical(y_train, 10)
y_test_class = np_utils.to_categorical(y_test, 10)

print('Image shape: {0}'.format(x_train.shape[1:]))
print('Total number of training samples: {0}'.format(x_train.shape[0]))
print('Total number of validation samples: {0}'.format(x_test.shape[0]))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-9-458b834a2915> in <cell line: 5>()
#       3 from keras.models import Sequential
#       4 from keras.layers import Dense, Dropout, Activation, BatchNormalization
# ----> 5 from keras.utils import np_utils
#       6 from keras.datasets import mnist
#       7 from keras.optimizers import RMSprop
#
# ImportError: cannot import name 'np_utils' from 'keras.utils' (/usr/local/lib/python3.10/dist-packages/keras/api/utils/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# As illustrated in the cell, this time the input image before the model is 28x28x1.
#
# Now we can define a model composed of convolutional layers, activation functions, and maxpool operators:

# %%
model = Sequential()
model.add(Conv2D(16, (3,3), padding='same', input_shape=x_train.shape[1:]))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(16, (3,3), padding='same'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-04eba811f7bd> in <cell line: 2>()
#       1 model = Sequential()
# ----> 2 model.add(Conv2D(16, (3,3), padding='same', input_shape=x_train.shape[1:]))
#       3 model.add(Activation('relu'))
#       4 model.add(MaxPooling2D(pool_size=(2,2)))
#       5 model.add(Conv2D(16, (3,3), padding='same'))
#
# NameError: name 'Conv2D' is not defined

# %% [markdown]
# As explained in the previous tutorial, in a classification problem, the output of the model is a probability vector. Each dimension of the vector indicates how likely is that the input image belongs to a specific class.
#
# Up to now, the resulting feature map of the model is a map with the shape *Batch x Weight' x Height' x Channel*, and it needs to be mapped into a vector with shape *Batch x Num Classes*. A common technique to process this mapping is to add a Flatten layer that will reshape the feature map to *Batch x (Weight' * Height' * Channel)*. Following the Flatten layer, we add a dense layer which maps this new feature map to the desired output size.

# %%
model.add(Flatten())
model.add(Dense(10))
model.add(Activation('softmax'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-c3d7b448029e> in <cell line: 1>()
# ----> 1 model.add(Flatten())
#       2 model.add(Dense(10))
#       3 model.add(Activation('softmax'))
#
# NameError: name 'Flatten' is not defined

# %% [markdown]
# Let's visualize the output shape in each layer.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 16)        160
# _________________________________________________________________
# activation (Activation)      (None, 28, 28, 16)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 14, 14, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 14, 14, 16)        2320
# _________________________________________________________________
# activation_1 (Activation)    (None, 14, 14, 16)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 7, 7, 16)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 784)               0
# _________________________________________________________________
# dense (Dense)                (None, 10)                7850
# _________________________________________________________________
# activation_2 (Activation)    (None, 10)                0
# =================================================================
# Total params: 10,330
# Trainable params: 10,330
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Finally, we can train our CNN and check its performance on MNIST.

# %%
# initiate RMSprop optimizer
opt = RMSprop(lr=0.0001, decay=1e-6)

model.compile(loss='categorical_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])

model.fit(x_train, y_train_class, batch_size=32, epochs=10,  verbose=0)

score = model.evaluate(x_test, y_test_class, verbose=0)
print('Validation loss:', score[0])
print('Validation accuracy:', score[1])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-36eadbf0acf4> in <cell line: 2>()
#       1 # initiate RMSprop optimizer
# ----> 2 opt = RMSprop(lr=0.0001, decay=1e-6)
#       3
#       4 model.compile(loss='categorical_crossentropy',
#       5               optimizer=opt,
#
# /usr/local/lib/python3.10/dist-packages/keras/src/optimizers/rmsprop.py in __init__(self, learning_rate, rho, momentum, epsilon, centered, weight_decay, clipnorm, clipvalue, global_clipnorm, use_ema, ema_momentum, ema_overwrite_frequency, loss_scale_factor, gradient_accumulation_steps, name, **kwargs)
#      70         **kwargs,
#      71     ):
# ---> 72         super().__init__(
#      73             learning_rate=learning_rate,
#      74             weight_decay=weight_decay,
#
# /usr/local/lib/python3.10/dist-packages/keras/src/backend/tensorflow/optimizer.py in __init__(self, *args, **kwargs)
#      20
#      21     def __init__(self, *args, **kwargs):
# ---> 22         super().__init__(*args, **kwargs)
#      23         self._distribution_strategy = tf.distribute.get_strategy()
#      24
#
# /usr/local/lib/python3.10/dist-packages/keras/src/optimizers/base_optimizer.py in __init__(self, learning_rate, weight_decay, clipnorm, clipvalue, global_clipnorm, use_ema, ema_momentum, ema_overwrite_frequency, loss_scale_factor, gradient_accumulation_steps, name, **kwargs)
#      35             )
#      36         if kwargs:
# ---> 37             raise ValueError(f"Argument(s) not recognized: {kwargs}")
#      38
#      39         if name is None:
#
# ValueError: Argument(s) not recognized: {'lr': 0.0001}

# %% [markdown]
# # Coursework

# %% [markdown]
# ## Task 1: Classification
#
# At this point, we know what is a CNN, how they work, and the components needed to design them. In this first task, we want you to create a CNN that is able to outperform the Multi-layer Perceptron model from Tutorial 1. For the first part of the coursework, we train on CIFAR10, a  classical dataset for image classification. Note that in these tutorials, we mainly use the official test sets of several standard datasets as our validation data. The reason we use the given test sets as validation data for the tutorials is that is an easy way to make sure that we all work with the same split and report results using the same data. However, in a proper machine learning setup, your validation set should be separate from the test set, so you can tune the model/parameters on the validation set and then check the final performance in the test set. Thus, even though the variables are `x_test` and `y_test`, they represent our validation set.
#
# Let's first load the dataset and visualise some examples:

# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation
# from keras.utils import np_utils
from tensorflow.keras.utils import to_categorical
from keras.datasets import cifar10
from keras.optimizers import RMSprop

# the data, shuffled and split between train and test sets
# Here we are using the official test set as our validation set, in further
# tutorials, test and validation splits will be explained properly.
# Hence, even though the variables are `x_test` and `y_test`, they represent our validation set
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

print('Image shape: {0}'.format(X_train.shape[1:]))
print('Total number of training samples: {0}'.format(X_train.shape[0]))
print('Total number of validation samples: {0}'.format(X_test.shape[0]))

# Let's visualize some examples
N=5
start_val = 0 # pick an element for the code to plot the following N**2 values
fig, axes = plt.subplots(N,N)
items = list(range(0, 10))
for row in range(N):
  for col in range(N):
    idx = start_val+row+N*col
    axes[row,col].imshow(X_train[idx], cmap='gray')
    fig.subplots_adjust(hspace=0.5)
    y_target = int(y_train[idx])
    target = str(items[y_target])
    axes[row,col].set_title(target)
    axes[row,col].set_xticks([])
    axes[row,col].set_yticks([])
# Out:
# Image shape: (32, 32, 3)
# Total number of training samples: 50000
# Total number of validation samples: 10000
# <ipython-input-12-67490d9fd31b>:32: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   y_target = int(y_train[idx])

# %% [markdown]
# CIFAR10 contains 50,000 32x32 color training images, labeled over 10 categories and 10,000 test images. As mentioned, we use those test images as our validation set in this tutorial. We need to preprocess the images for the 1D neural network defined in the previous tutorial:

# %%
# Preprocess dataset for a 1D neural network
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

# Normalize the image
X_train /= 255
X_test /= 255

X_train_flatten = X_train.reshape(X_train.shape[0], X_train.shape[1] * X_train.shape[2]*3)
X_test_flatten = X_test.reshape(X_test.shape[0], X_test.shape[1] * X_test.shape[2]*3)

print('New X_train shape: {0}'.format(X_train_flatten.shape))

# Y_train_class = np_utils.to_categorical(y_train, 10)
# Y_test_class = np_utils.to_categorical(y_test, 10)

# print('New Y_train shape: {0}'.format(Y_train_class.shape))
Y_train_class = to_categorical(y_train, 10)
Y_test_class = to_categorical(y_test, 10)

print('New Y_train shape: {0}'.format(Y_train_class.shape))
# Out:
# New X_train shape: (50000, 3072)
# New Y_train shape: (50000, 10)

# %% [markdown]
# Now, we are ready to define the Multi-layer Perceptron model and train it.

# %%
model = Sequential()

model.add(Dense(32, activation='relu', input_shape=(X_train_flatten.shape[1:])))
model.add(Dense(64, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(256, activation='relu'))
model.add(Dense(512, activation='relu'))
model.add(Dense(10, activation='softmax'))

# initiate RMSprop optimizer
opt = RMSprop(learning_rate=0.0001, decay=1e-6)

# Let's train the model using RMSprop
model.compile(loss='categorical_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])

model.fit(X_train_flatten, Y_train_class, batch_size=32, epochs=20)

score = model.evaluate(X_test_flatten, Y_test_class, verbose=0)
print('Validation loss:', score[0])
print('Validation accuracy:', score[1])
# Out:
# Epoch 1/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.2456 - loss: 2.0376
# Epoch 2/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.3653 - loss: 1.7712
# Epoch 3/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.3959 - loss: 1.6891
# Epoch 4/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.4162 - loss: 1.6357
# Epoch 5/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.4344 - loss: 1.5825
# Epoch 6/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.4459 - loss: 1.5507
# Epoch 7/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.4583 - loss: 1.5125
# Epoch 8/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.4684 - loss: 1.4904
# Epoch 9/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.4732 - loss: 1.4692
# Epoch 10/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.4841 - loss: 1.4481
# Epoch 11/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.4917 - loss: 1.4296
# Epoch 12/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.4989 - loss: 1.4097
# Epoch 13/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.5067 - loss: 1.3911
# Epoch 14/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.5127 - loss: 1.3704
# Epoch 15/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.5180 - loss: 1.3551
# Epoch 16/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.5186 - loss: 1.3483
# Epoch 17/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.5274 - loss: 1.3281
# Epoch 18/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.5285 - loss: 1.3183
# Epoch 19/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.5387 - loss: 1.3055
# Epoch 20/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.5354 - loss: 1.2965
# Validation loss: 1.395719289779663
# Validation accuracy: 0.5037999749183655

# %% [markdown]
# ### Problem Definition
#
# In this exercise, you are asked to test several CNN architectures in the code provided below. Do not modify the optimizer, loss used or parameters related to the training such as the learning rate, they will be investigated in future tutorials. You must focus on the architecture itself: number of convolutional layers, number of filters in every layer, activation functions, pooling operators, among others. Batch Normalization and Dropout layers, which are quite used in CNN architectures, will be also investigated in a future tutorial so you do not have to discuss them.
#
#
# **Report**:
# *   Present a bar figure with the training and validation accuracies for different design choices. Discuss only the parameters that have a significant influence on the network's performance. Explain any discrepancy between training and validation accuracies.
# *   Present a sketch that introduces your best architecture. See some examples on how to display networks in [cv-tricks' blog](https://cv-tricks.com/cnn/understand-resnet-alexnet-vgg-inception/).

# %%
import tensorflow as tf
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
from keras.models import Sequential
from keras.layers import Dense, Activation
from tensorflow.keras.utils import to_categorical
from keras.datasets import cifar10
from keras.optimizers import RMSprop
from keras.layers import Conv2D, MaxPooling2D, Flatten
import matplotlib.pyplot as plt

# the data, shuffled and split between train and val sets
# Here we are using the official test set as our validation set, in further
# tutorials, test and validation splits will be explained properly.
# Hence, even though the variables are `x_test` and `y_test`, they represent our validation set
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

print('Image shape: {0}'.format(x_train.shape[1:]))
print('Total number of training samples: {0}'.format(x_train.shape[0]))
print('Total number of validation samples: {0}'.format(x_test.shape[0]))

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')

# Normalize the image
x_train /= 255
x_test /= 255

# y_train_class = np_utils.to_categorical(y_train, 10)
# y_test_class = np_utils.to_categorical(y_test, 10)
y_train_class = to_categorical(y_train, 10)
y_test_class = to_categorical(y_test, 10)


# . . .


# Define here your architecture
architectures = [
    # Varying the number of convolutional layers
    {
        'name': 'Model_1_Fewer_Conv_Layers',
        'model': Sequential([
            Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(32, 32, 3)),
            MaxPooling2D(pool_size=(2, 2)),
            Flatten(),
            Dense(128, activation='relu'),
            Dense(10, activation='softmax')
        ])
    },
    {
        'name': 'Model_2_More_Conv_Layers',
        'model': Sequential([
            Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(32, 32, 3)),
            MaxPooling2D(pool_size=(2, 2)),
            Conv2D(64, (3, 3), activation='relu', padding='same'),
            MaxPooling2D(pool_size=(2, 2)),
            Flatten(),
            Dense(128, activation='relu'),
            Dense(10, activation='softmax')
        ])
    },
    # Varying the number of filters per layer
    {
        'name': 'Model_3_Less_Filters',
        'model': Sequential([
            Conv2D(16, (3, 3), activation='relu', padding='same', input_shape=(32, 32, 3)),
            MaxPooling2D(pool_size=(2, 2)),
            Conv2D(32, (3, 3), activation='relu', padding='same'),
            MaxPooling2D(pool_size=(2, 2)),
            Flatten(),
            Dense(128, activation='relu'),
            Dense(10, activation='softmax')
        ])
    },
    {
        'name': 'Model_4_More_Filters',
        'model': Sequential([
            Conv2D(64, (3, 3), activation='relu', padding='same', input_shape=(32, 32, 3)),
            MaxPooling2D(pool_size=(2, 2)),
            Conv2D(128, (3, 3), activation='relu', padding='same'),
            MaxPooling2D(pool_size=(2, 2)),
            Flatten(),
            Dense(128, activation='relu'),
            Dense(10, activation='softmax')
        ])
    },
    # Varying activation functions
    {
        'name': 'Model_5_ReLU',
        'model': Sequential([
            Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(32, 32, 3)),
            MaxPooling2D(pool_size=(2, 2)),
            Conv2D(64, (3, 3), activation='relu', padding='same'),
            MaxPooling2D(pool_size=(2, 2)),
            Flatten(),
            Dense(128, activation='relu'),
            Dense(10, activation='softmax')
        ])
    },
    {
        'name': 'Model_6_Tanh',
        'model': Sequential([
            Conv2D(32, (3, 3), activation='tanh', padding='same', input_shape=(32, 32, 3)),
            MaxPooling2D(pool_size=(2, 2)),
            Conv2D(64, (3, 3), activation='tanh', padding='same'),
            MaxPooling2D(pool_size=(2, 2)),
            Flatten(),
            Dense(128, activation='tanh'),
            Dense(10, activation='softmax')
        ])
    },
    # Varying pooling operators
    {
        'name': 'Model_7_MaxPooling',
        'model': Sequential([
            Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(32, 32, 3)),
            MaxPooling2D(pool_size=(2, 2)),
            Conv2D(64, (3, 3), activation='relu', padding='same'),
            MaxPooling2D(pool_size=(2, 2)),
            Flatten(),
            Dense(128, activation='relu'),
            Dense(10, activation='softmax')
        ])
    },
    {
        'name': 'Model_8_AvgPooling',
        'model': Sequential([
            Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(32, 32, 3)),
            tf.keras.layers.AvgPool2D(pool_size=(2, 2)),
            Conv2D(64, (3, 3), activation='relu', padding='same'),
            tf.keras.layers.AvgPool2D(pool_size=(2, 2)),
            Flatten(),
            Dense(128, activation='relu'),
            Dense(10, activation='softmax')
        ])
    }
]

# opt = RMSprop(learning_rate=0.0001, decay=1e-6)
batch_size = 32
epochs = 20

# . . .
# Store results
results = []

# Train and evaluate each architecture
# Train and evaluate each architecture
for arch in architectures:
    print(f"Training {arch['name']} model...")
    model = arch['model']

    # Create a new optimizer instance for each model
    opt = RMSprop(learning_rate=0.0001, decay=1e-6)

    model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
    history = model.fit(
        x_train, y_train_class,
        batch_size=batch_size,
        epochs=epochs,
        validation_data=(x_test, y_test_class),
        verbose=0
    )

    # Save training and validation accuracy
    train_acc = history.history['accuracy'][-1]
    val_acc = history.history['val_accuracy'][-1]
    results.append({
        'name': arch['name'],
        'train_accuracy': train_acc,
        'val_accuracy': val_acc
    })
    print(f"{arch['name']} - Train Accuracy: {train_acc:.4f}, Validation Accuracy: {val_acc:.4f}\n")

# Plot the results
architectures = [res['name'] for res in results]
train_accuracies = [res['train_accuracy'] for res in results]
val_accuracies = [res['val_accuracy'] for res in results]

x = range(len(architectures))
plt.bar(x, train_accuracies, width=0.4, label='Training Accuracy', align='center')
plt.bar(x, val_accuracies, width=0.4, label='Validation Accuracy', align='edge')
plt.xticks(x, architectures)
plt.xlabel('Architectures')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracies for Different Architectures')
plt.legend()
plt.show()

# Discussion of Results
print("\nDiscussion of Results:")
for res in results:
    discrepancy = abs(res['train_accuracy'] - res['val_accuracy'])
    print(f"{res['name']} Model: Training Accuracy = {res['train_accuracy']:.4f}, Validation Accuracy = {res['val_accuracy']:.4f}, Discrepancy = {discrepancy:.4f}")
    if discrepancy > 0.05:
        print(f"    -> Significant overfitting observed. Consider reducing model complexity or adding regularization.")
    else:
        print(f"    -> Well-balanced training and validation performance.")

# model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

# model.fit(x_train, y_train_class, batch_size=32, epochs=20)

# score = model.evaluate(x_test, y_test_class, verbose=0)
# print('Validation loss:', score[0])
# print('Validation accuracy:', score[1])
# Out:
# Image shape: (32, 32, 3)
# Total number of training samples: 50000
# Total number of validation samples: 10000
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Training Model_1_Fewer_Conv_Layers model...
# /usr/local/lib/python3.10/dist-packages/keras/src/optimizers/base_optimizer.py:33: UserWarning: Argument `decay` is no longer supported and will be ignored.
#   warnings.warn(
# Epoch 1/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.3207 - loss: 1.9093 - val_accuracy: 0.4403 - val_loss: 1.5889
# Epoch 2/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.4691 - loss: 1.5200 - val_accuracy: 0.4889 - val_loss: 1.4290
# Epoch 3/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5179 - loss: 1.3791 - val_accuracy: 0.5053 - val_loss: 1.3830
# Epoch 4/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.5593 - loss: 1.2795 - val_accuracy: 0.5621 - val_loss: 1.2491
# Epoch 5/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.5809 - loss: 1.2118 - val_accuracy: 0.5757 - val_loss: 1.2211
# Epoch 6/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.6053 - loss: 1.1468 - val_accuracy: 0.5860 - val_loss: 1.1699
# Epoch 7/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.6203 - loss: 1.1080 - val_accuracy: 0.5938 - val_loss: 1.1621
# Epoch 8/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.6317 - loss: 1.0613 - val_accuracy: 0.6109 - val_loss: 1.1228
# Epoch 9/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.6466 - loss: 1.0302 - val_accuracy: 0.6009 - val_loss: 1.1410
# Epoch 10/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.6545 - loss: 1.0047 - val_accuracy: 0.6205 - val_loss: 1.0842
# Epoch 11/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.6704 - loss: 0.9590 - val_accuracy: 0.6161 - val_loss: 1.0898
# Epoch 12/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - accuracy: 0.6765 - loss: 0.9423 - val_accuracy: 0.6225 - val_loss: 1.0884
# Epoch 13/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.6859 - loss: 0.9127 - val_accuracy: 0.6274 - val_loss: 1.0688
# Epoch 14/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.6908 - loss: 0.8945 - val_accuracy: 0.6307 - val_loss: 1.0587
# Epoch 15/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.6989 - loss: 0.8692 - val_accuracy: 0.6494 - val_loss: 1.0162
# Epoch 16/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7122 - loss: 0.8470 - val_accuracy: 0.6527 - val_loss: 1.0178
# Epoch 17/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.7187 - loss: 0.8235 - val_accuracy: 0.6510 - val_loss: 1.0051
# Epoch 18/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.7290 - loss: 0.8029 - val_accuracy: 0.6606 - val_loss: 0.9816
# Epoch 19/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7362 - loss: 0.7816 - val_accuracy: 0.6529 - val_loss: 1.0037
# Epoch 20/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7443 - loss: 0.7556 - val_accuracy: 0.6606 - val_loss: 0.9874
# Model_1_Fewer_Conv_Layers - Train Accuracy: 0.7390, Validation Accuracy: 0.6606
#
# Training Model_2_More_Conv_Layers model...
# Epoch 1/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.3137 - loss: 1.9335 - val_accuracy: 0.4577 - val_loss: 1.5453
# Epoch 2/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.4822 - loss: 1.4749 - val_accuracy: 0.5080 - val_loss: 1.3851
# Epoch 3/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5371 - loss: 1.3221 - val_accuracy: 0.5530 - val_loss: 1.2720
# Epoch 4/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.5721 - loss: 1.2240 - val_accuracy: 0.5719 - val_loss: 1.2043
# Epoch 5/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.6012 - loss: 1.1453 - val_accuracy: 0.5981 - val_loss: 1.1485
# Epoch 6/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.6242 - loss: 1.0836 - val_accuracy: 0.6049 - val_loss: 1.1046
# Epoch 7/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.6447 - loss: 1.0232 - val_accuracy: 0.6396 - val_loss: 1.0369
# Epoch 8/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.6649 - loss: 0.9767 - val_accuracy: 0.6178 - val_loss: 1.0722
# Epoch 9/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.6731 - loss: 0.9447 - val_accuracy: 0.6532 - val_loss: 0.9864
# Epoch 10/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.6855 - loss: 0.9095 - val_accuracy: 0.6548 - val_loss: 0.9690
# Epoch 11/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.6976 - loss: 0.8769 - val_accuracy: 0.6733 - val_loss: 0.9421
# Epoch 12/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.7088 - loss: 0.8496 - val_accuracy: 0.6698 - val_loss: 0.9570
# Epoch 13/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7162 - loss: 0.8223 - val_accuracy: 0.6764 - val_loss: 0.9249
# Epoch 14/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.7324 - loss: 0.7817 - val_accuracy: 0.6802 - val_loss: 0.9314
# Epoch 15/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7362 - loss: 0.7657 - val_accuracy: 0.6829 - val_loss: 0.9243
# Epoch 16/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7449 - loss: 0.7395 - val_accuracy: 0.6949 - val_loss: 0.8930
# Epoch 17/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7518 - loss: 0.7193 - val_accuracy: 0.6629 - val_loss: 0.9639
# Epoch 18/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7572 - loss: 0.7043 - val_accuracy: 0.6891 - val_loss: 0.9050
# Epoch 19/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7644 - loss: 0.6848 - val_accuracy: 0.6884 - val_loss: 0.9033
# Epoch 20/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7768 - loss: 0.6582 - val_accuracy: 0.6876 - val_loss: 0.9161
# Model_2_More_Conv_Layers - Train Accuracy: 0.7747, Validation Accuracy: 0.6876
#
# Training Model_3_Less_Filters model...
# Epoch 1/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.2864 - loss: 2.0073 - val_accuracy: 0.4224 - val_loss: 1.6571
# Epoch 2/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.4340 - loss: 1.5995 - val_accuracy: 0.4668 - val_loss: 1.5056
# Epoch 3/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.4891 - loss: 1.4560 - val_accuracy: 0.4838 - val_loss: 1.4682
# Epoch 4/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5232 - loss: 1.3584 - val_accuracy: 0.5375 - val_loss: 1.3038
# Epoch 5/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.5516 - loss: 1.2849 - val_accuracy: 0.5603 - val_loss: 1.2446
# Epoch 6/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5712 - loss: 1.2270 - val_accuracy: 0.5426 - val_loss: 1.3465
# Epoch 7/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5909 - loss: 1.1789 - val_accuracy: 0.5807 - val_loss: 1.1845
# Epoch 8/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.5998 - loss: 1.1481 - val_accuracy: 0.5957 - val_loss: 1.1506
# Epoch 9/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.6097 - loss: 1.1136 - val_accuracy: 0.5981 - val_loss: 1.1383
# Epoch 10/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.6213 - loss: 1.0868 - val_accuracy: 0.5900 - val_loss: 1.1477
# Epoch 11/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.6298 - loss: 1.0644 - val_accuracy: 0.5985 - val_loss: 1.1338
# Epoch 12/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.6410 - loss: 1.0352 - val_accuracy: 0.6112 - val_loss: 1.1150
# Epoch 13/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.6472 - loss: 1.0147 - val_accuracy: 0.6183 - val_loss: 1.0898
# Epoch 14/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.6582 - loss: 0.9861 - val_accuracy: 0.6384 - val_loss: 1.0365
# Epoch 15/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.6644 - loss: 0.9685 - val_accuracy: 0.6153 - val_loss: 1.0928
# Epoch 16/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.6680 - loss: 0.9572 - val_accuracy: 0.6402 - val_loss: 1.0360
# Epoch 17/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.6794 - loss: 0.9287 - val_accuracy: 0.6358 - val_loss: 1.0458
# Epoch 18/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.6812 - loss: 0.9219 - val_accuracy: 0.6468 - val_loss: 1.0199
# Epoch 19/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.6933 - loss: 0.8896 - val_accuracy: 0.6280 - val_loss: 1.0590
# Epoch 20/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7006 - loss: 0.8676 - val_accuracy: 0.6556 - val_loss: 0.9908
# Model_3_Less_Filters - Train Accuracy: 0.6966, Validation Accuracy: 0.6556
#
# Training Model_4_More_Filters model...
# Epoch 1/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.3284 - loss: 1.8715 - val_accuracy: 0.4784 - val_loss: 1.4660
# Epoch 2/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.5098 - loss: 1.3885 - val_accuracy: 0.5623 - val_loss: 1.2364
# Epoch 3/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.5714 - loss: 1.2180 - val_accuracy: 0.5512 - val_loss: 1.2471
# Epoch 4/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.6105 - loss: 1.1104 - val_accuracy: 0.5881 - val_loss: 1.1506
# Epoch 5/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.6448 - loss: 1.0245 - val_accuracy: 0.6061 - val_loss: 1.0867
# Epoch 6/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.6653 - loss: 0.9638 - val_accuracy: 0.6482 - val_loss: 1.0047
# Epoch 7/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.6873 - loss: 0.9064 - val_accuracy: 0.6712 - val_loss: 0.9434
# Epoch 8/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.7047 - loss: 0.8533 - val_accuracy: 0.6644 - val_loss: 0.9492
# Epoch 9/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7240 - loss: 0.8040 - val_accuracy: 0.6952 - val_loss: 0.8890
# Epoch 10/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7389 - loss: 0.7712 - val_accuracy: 0.6815 - val_loss: 0.9203
# Epoch 11/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.7441 - loss: 0.7422 - val_accuracy: 0.6908 - val_loss: 0.8932
# Epoch 12/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7598 - loss: 0.7046 - val_accuracy: 0.7073 - val_loss: 0.8510
# Epoch 13/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.7742 - loss: 0.6687 - val_accuracy: 0.7132 - val_loss: 0.8351
# Epoch 14/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7825 - loss: 0.6416 - val_accuracy: 0.7042 - val_loss: 0.8505
# Epoch 15/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.7900 - loss: 0.6109 - val_accuracy: 0.7024 - val_loss: 0.8691
# Epoch 16/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.7980 - loss: 0.5919 - val_accuracy: 0.7249 - val_loss: 0.8085
# Epoch 17/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.8084 - loss: 0.5643 - val_accuracy: 0.7101 - val_loss: 0.8600
# Epoch 18/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8204 - loss: 0.5321 - val_accuracy: 0.7280 - val_loss: 0.8139
# Epoch 19/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.8320 - loss: 0.4947 - val_accuracy: 0.7248 - val_loss: 0.8153
# Epoch 20/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8399 - loss: 0.4726 - val_accuracy: 0.7246 - val_loss: 0.8312
# Model_4_More_Filters - Train Accuracy: 0.8367, Validation Accuracy: 0.7246
#
# Training Model_5_ReLU model...
# Epoch 1/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.3096 - loss: 1.9289 - val_accuracy: 0.4510 - val_loss: 1.5461
# Epoch 2/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.4683 - loss: 1.5005 - val_accuracy: 0.5204 - val_loss: 1.3634
# Epoch 3/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.5311 - loss: 1.3340 - val_accuracy: 0.5388 - val_loss: 1.3021
# Epoch 4/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5693 - loss: 1.2336 - val_accuracy: 0.5788 - val_loss: 1.1987
# Epoch 5/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.5932 - loss: 1.1625 - val_accuracy: 0.5991 - val_loss: 1.1523
# Epoch 6/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.6139 - loss: 1.1106 - val_accuracy: 0.6116 - val_loss: 1.1159
# Epoch 7/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.6305 - loss: 1.0589 - val_accuracy: 0.6144 - val_loss: 1.1180
# Epoch 8/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.6445 - loss: 1.0227 - val_accuracy: 0.6127 - val_loss: 1.1012
# Epoch 9/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.6553 - loss: 0.9870 - val_accuracy: 0.6547 - val_loss: 0.9985
# Epoch 10/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.6747 - loss: 0.9352 - val_accuracy: 0.6488 - val_loss: 1.0177
# Epoch 11/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.6825 - loss: 0.9164 - val_accuracy: 0.6590 - val_loss: 0.9823
# Epoch 12/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.6989 - loss: 0.8738 - val_accuracy: 0.6642 - val_loss: 0.9753
# Epoch 13/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7058 - loss: 0.8534 - val_accuracy: 0.6717 - val_loss: 0.9440
# Epoch 14/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7179 - loss: 0.8221 - val_accuracy: 0.6783 - val_loss: 0.9264
# Epoch 15/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7190 - loss: 0.8048 - val_accuracy: 0.6537 - val_loss: 0.9984
# Epoch 16/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7309 - loss: 0.7778 - val_accuracy: 0.6974 - val_loss: 0.9008
# Epoch 17/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7436 - loss: 0.7498 - val_accuracy: 0.6854 - val_loss: 0.9249
# Epoch 18/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7549 - loss: 0.7188 - val_accuracy: 0.6799 - val_loss: 0.9233
# Epoch 19/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7576 - loss: 0.6966 - val_accuracy: 0.7024 - val_loss: 0.8615
# Epoch 20/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7625 - loss: 0.6897 - val_accuracy: 0.7050 - val_loss: 0.8627
# Model_5_ReLU - Train Accuracy: 0.7618, Validation Accuracy: 0.7050
#
# Training Model_6_Tanh model...
# Epoch 1/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.3651 - loss: 1.8102 - val_accuracy: 0.4800 - val_loss: 1.4681
# Epoch 2/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.5230 - loss: 1.3830 - val_accuracy: 0.5314 - val_loss: 1.3161
# Epoch 3/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.5705 - loss: 1.2411 - val_accuracy: 0.5729 - val_loss: 1.2216
# Epoch 4/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.6012 - loss: 1.1462 - val_accuracy: 0.6011 - val_loss: 1.1382
# Epoch 5/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.6256 - loss: 1.0795 - val_accuracy: 0.6103 - val_loss: 1.1310
# Epoch 6/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.6477 - loss: 1.0235 - val_accuracy: 0.6247 - val_loss: 1.0864
# Epoch 7/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.6583 - loss: 0.9903 - val_accuracy: 0.6467 - val_loss: 1.0181
# Epoch 8/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.6717 - loss: 0.9455 - val_accuracy: 0.6553 - val_loss: 0.9941
# Epoch 9/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.6848 - loss: 0.9140 - val_accuracy: 0.6545 - val_loss: 1.0049
# Epoch 10/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.6941 - loss: 0.8845 - val_accuracy: 0.6492 - val_loss: 1.0054
# Epoch 11/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7091 - loss: 0.8494 - val_accuracy: 0.6727 - val_loss: 0.9552
# Epoch 12/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7170 - loss: 0.8204 - val_accuracy: 0.6738 - val_loss: 0.9509
# Epoch 13/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7261 - loss: 0.7984 - val_accuracy: 0.6830 - val_loss: 0.9292
# Epoch 14/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7397 - loss: 0.7670 - val_accuracy: 0.6767 - val_loss: 0.9385
# Epoch 15/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.7439 - loss: 0.7448 - val_accuracy: 0.6831 - val_loss: 0.9244
# Epoch 16/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7551 - loss: 0.7238 - val_accuracy: 0.6881 - val_loss: 0.9004
# Epoch 17/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7607 - loss: 0.7033 - val_accuracy: 0.6925 - val_loss: 0.9068
# Epoch 18/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.7698 - loss: 0.6764 - val_accuracy: 0.6904 - val_loss: 0.9060
# Epoch 19/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.7815 - loss: 0.6435 - val_accuracy: 0.6978 - val_loss: 0.8848
# Epoch 20/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7895 - loss: 0.6258 - val_accuracy: 0.6963 - val_loss: 0.8913
# Model_6_Tanh - Train Accuracy: 0.7870, Validation Accuracy: 0.6963
#
# Training Model_7_MaxPooling model...
# Epoch 1/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.3089 - loss: 1.9195 - val_accuracy: 0.4709 - val_loss: 1.4836
# Epoch 2/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.4896 - loss: 1.4486 - val_accuracy: 0.5252 - val_loss: 1.3370
# Epoch 3/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.5435 - loss: 1.2938 - val_accuracy: 0.5758 - val_loss: 1.2148
# Epoch 4/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.5831 - loss: 1.1976 - val_accuracy: 0.6000 - val_loss: 1.1482
# Epoch 5/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.6046 - loss: 1.1295 - val_accuracy: 0.6083 - val_loss: 1.1318
# Epoch 6/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.6244 - loss: 1.0815 - val_accuracy: 0.6241 - val_loss: 1.0790
# Epoch 7/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.6427 - loss: 1.0299 - val_accuracy: 0.6381 - val_loss: 1.0560
# Epoch 8/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.6598 - loss: 0.9772 - val_accuracy: 0.6550 - val_loss: 1.0106
# Epoch 9/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.6750 - loss: 0.9437 - val_accuracy: 0.6641 - val_loss: 0.9777
# Epoch 10/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.6929 - loss: 0.8991 - val_accuracy: 0.6745 - val_loss: 0.9507
# Epoch 11/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.7017 - loss: 0.8666 - val_accuracy: 0.6654 - val_loss: 0.9667
# Epoch 12/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.7108 - loss: 0.8398 - val_accuracy: 0.6569 - val_loss: 0.9882
# Epoch 13/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7184 - loss: 0.8154 - val_accuracy: 0.6838 - val_loss: 0.9297
# Epoch 14/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7311 - loss: 0.7828 - val_accuracy: 0.6821 - val_loss: 0.9307
# Epoch 15/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.7396 - loss: 0.7576 - val_accuracy: 0.6843 - val_loss: 0.9229
# Epoch 16/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7508 - loss: 0.7282 - val_accuracy: 0.6998 - val_loss: 0.8862
# Epoch 17/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7584 - loss: 0.7062 - val_accuracy: 0.7022 - val_loss: 0.8694
# Epoch 18/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7660 - loss: 0.6827 - val_accuracy: 0.6910 - val_loss: 0.9104
# Epoch 19/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.7717 - loss: 0.6765 - val_accuracy: 0.6939 - val_loss: 0.9058
# Epoch 20/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7804 - loss: 0.6458 - val_accuracy: 0.7102 - val_loss: 0.8748
# Model_7_MaxPooling - Train Accuracy: 0.7774, Validation Accuracy: 0.7102
#
# Training Model_8_AvgPooling model...
# Epoch 1/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.3060 - loss: 1.9482 - val_accuracy: 0.3735 - val_loss: 1.6941
# Epoch 2/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.4461 - loss: 1.5669 - val_accuracy: 0.4836 - val_loss: 1.4452
# Epoch 3/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.4939 - loss: 1.4329 - val_accuracy: 0.5130 - val_loss: 1.3757
# Epoch 4/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.5224 - loss: 1.3506 - val_accuracy: 0.5373 - val_loss: 1.3058
# Epoch 5/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.5481 - loss: 1.2780 - val_accuracy: 0.5523 - val_loss: 1.2823
# Epoch 6/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5646 - loss: 1.2339 - val_accuracy: 0.5466 - val_loss: 1.2543
# Epoch 7/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5839 - loss: 1.1902 - val_accuracy: 0.5810 - val_loss: 1.1869
# Epoch 8/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.5959 - loss: 1.1517 - val_accuracy: 0.5879 - val_loss: 1.1757
# Epoch 9/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.6117 - loss: 1.1145 - val_accuracy: 0.5910 - val_loss: 1.1410
# Epoch 10/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.6268 - loss: 1.0672 - val_accuracy: 0.6059 - val_loss: 1.1182
# Epoch 11/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.6358 - loss: 1.0559 - val_accuracy: 0.6153 - val_loss: 1.1044
# Epoch 12/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.6433 - loss: 1.0220 - val_accuracy: 0.6036 - val_loss: 1.1173
# Epoch 13/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.6479 - loss: 1.0074 - val_accuracy: 0.6202 - val_loss: 1.0805
# Epoch 14/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.6641 - loss: 0.9625 - val_accuracy: 0.6341 - val_loss: 1.0338
# Epoch 15/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.6761 - loss: 0.9428 - val_accuracy: 0.6431 - val_loss: 1.0081
# Epoch 16/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.6819 - loss: 0.9210 - val_accuracy: 0.6390 - val_loss: 1.0244
# Epoch 17/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.6882 - loss: 0.9062 - val_accuracy: 0.6448 - val_loss: 1.0128
# Epoch 18/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.6959 - loss: 0.8800 - val_accuracy: 0.6551 - val_loss: 0.9871
# Epoch 19/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.7028 - loss: 0.8601 - val_accuracy: 0.6526 - val_loss: 1.0056
# Epoch 20/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7090 - loss: 0.8482 - val_accuracy: 0.6487 - val_loss: 1.0078
# Model_8_AvgPooling - Train Accuracy: 0.7088, Validation Accuracy: 0.6487
# Discussion of Results:
# Model_1_Fewer_Conv_Layers Model: Training Accuracy = 0.7390, Validation Accuracy = 0.6606, Discrepancy = 0.0784
#     -> Significant overfitting observed. Consider reducing model complexity or adding regularization.
# Model_2_More_Conv_Layers Model: Training Accuracy = 0.7747, Validation Accuracy = 0.6876, Discrepancy = 0.0871
#     -> Significant overfitting observed. Consider reducing model complexity or adding regularization.
# Model_3_Less_Filters Model: Training Accuracy = 0.6966, Validation Accuracy = 0.6556, Discrepancy = 0.0410
#     -> Well-balanced training and validation performance.
# Model_4_More_Filters Model: Training Accuracy = 0.8367, Validation Accuracy = 0.7246, Discrepancy = 0.1121
#     -> Significant overfitting observed. Consider reducing model complexity or adding regularization.
# Model_5_ReLU Model: Training Accuracy = 0.7618, Validation Accuracy = 0.7050, Discrepancy = 0.0568
#     -> Significant overfitting observed. Consider reducing model complexity or adding regularization.
# Model_6_Tanh Model: Training Accuracy = 0.7870, Validation Accuracy = 0.6963, Discrepancy = 0.0907
#     -> Significant overfitting observed. Consider reducing model complexity or adding regularization.
# Model_7_MaxPooling Model: Training Accuracy = 0.7774, Validation Accuracy = 0.7102, Discrepancy = 0.0672
#     -> Significant overfitting observed. Consider reducing model complexity or adding regularization.
# Model_8_AvgPooling Model: Training Accuracy = 0.7088, Validation Accuracy = 0.6487, Discrepancy = 0.0601
#     -> Significant overfitting observed. Consider reducing model complexity or adding regularization.

# %% [markdown]
# ---
# ---
#
# ## Task 2: Regression
#
# Now we face a regression task instead of a classification problem. Loss function, activations, and dataset will change in the following task. Thus, instead of having one vector with the probabilities of each class, in this regression problem, the output is a single scalar.
#
# For this second task, we chose the task of estimating house prices based on input images. To get the data run the following script, which clones Ahmed and Moustafa’s [repository](https://github.com/emanhamed/Houses-dataset) into colmap.

# %%
# !git clone https://github.com/emanhamed/Houses-dataset
# %cd /content/Houses-dataset/Houses\ Dataset
# Out:
# Cloning into 'Houses-dataset'...
# remote: Enumerating objects: 2166, done.
# remote: Counting objects: 100% (1/1), done.
# remote: Total 2166 (delta 0), reused 0 (delta 0), pack-reused 2165 (from 1)
# Receiving objects: 100% (2166/2166), 176.26 MiB | 36.10 MiB/s, done.
# Resolving deltas: 100% (20/20), done.
# /content/Houses-dataset/Houses Dataset

# %% [markdown]
# This dataset contains four images of the house (kitchen, frontal, bedroom and bathroom), and attributes (number of bedrooms, number of bathrooms, zip code...). For our exercise, we only use the images of the house. We start with front door images.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from numpy.random import seed

house_section = 'frontal' # select between: kitchen, frontal, bedroom or bathroom
print('We have selected {} images. You can switch to the kitchen, frontal, bedroom or bathroom images by changing house_section variable.'.format(house_section))
images = []
for i_im in range(1, 536):
  image = cv2.imread(str(i_im)+'_'+house_section+'.jpg')
  image = cv2.resize(image, (64, 64))
  images.append(image)

labels = []
f = open('HousesInfo.txt', "r")
for x in f:
  label = (x).split(' ')[-1].split('\n')[0]
  labels.append(label)

# Let's visualize some examples
N=3
start_val = 0 # pick an element for the code to plot the following N**2 values
fig, axes = plt.subplots(N,N)
for row in range(N):
  for col in range(N):
    idx = start_val+row+N*col
    tmp = cv2.cvtColor(images[idx],cv2.COLOR_BGR2RGB)
    axes[row,col].imshow(tmp, cmap='gray')
    fig.subplots_adjust(hspace=0.5)
    target = int(labels[idx])
    axes[row,col].set_title(str(target) + '$')
    axes[row,col].set_xticks([])
    axes[row,col].set_yticks([])
# Out:
# We have selected frontal images. You can switch to the kitchen, frontal, bedroom or bathroom images by changing house_section variable.

# %% [markdown]
# Prepare the dataset for training the model:

# %%
seed(1234)
images = np.asarray(images).astype('float32')
labels = np.asarray(labels).astype('float32')

# Normalize the image
max_price = labels.max()
images /= 255.
labels /= max_price

random_idx = np.random.permutation(len(images))
images = images[random_idx]
labels = labels[random_idx]

split_size_val = int(0.8*len(images))
X_train, X_val = images[:split_size_val], images[split_size_val+1:]
Y_train, Y_val = labels[:split_size_val], labels[split_size_val+1:]

# Print shape of training and val images
print('X_train image shape: {0}'.format(X_train.shape))
print('X_val image shape: {0}'.format(X_val.shape))

# Print shape of training and val labels
print('Y_train labels shape: {0}'.format(Y_train.shape))
print('Y_val labels shape: {0}'.format(Y_val.shape))
# Out:
# X_train image shape: (428, 64, 64, 3)
# X_val image shape: (106, 64, 64, 3)
# Y_train labels shape: (428,)
# Y_val labels shape: (106,)

# %% [markdown]
# ### Problem Definition
#
# Similar to the previous task, you are asked to design a CNN architecture able to perform the estimation of house prices based on the `frontal` house image. Design a new model by changing parameters such as the number of convolutional layers, activation functions, strides, or pooling operators, among others.

# %%
import tensorflow as tf
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
from keras.models import Sequential
from keras.layers import Dense, Activation
from tensorflow.keras.utils import to_categorical
from keras.optimizers import Adam
from keras.layers import Conv2D, MaxPooling2D, Flatten
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# tf.random.set_seed(1234)

chanDim = -1
# model = Sequential()

# . . .
seed = 1234
np.random.seed(seed)

# Split the data into training and validation sets
split_size_val = int(0.8 * len(images))
X_train, X_val = images[:split_size_val], images[split_size_val+1:]
Y_train, Y_val = labels[:split_size_val], labels[split_size_val+1:]

# Print shape of training and validation images and labels
print('X_train image shape: {0}'.format(X_train.shape))
print('X_val image shape: {0}'.format(X_val.shape))
print('Y_train labels shape: {0}'.format(Y_train.shape))
print('Y_val labels shape: {0}'.format(Y_val.shape))

# Define architectures for the regression task
architectures = [
    # Varying the number of convolutional layers
    {
        'name': 'Fewer_Conv_Layers',
        'model': Sequential([
            Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(64, 64, 3)),
            MaxPooling2D(pool_size=(2, 2)),
            Flatten(),
            Dense(128, activation='relu'),
            Dense(1, activation='linear')
        ])
    },
    {
        'name': 'More_Conv_Layers',
        'model': Sequential([
            Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(64, 64, 3)),
            MaxPooling2D(pool_size=(2, 2)),
            Conv2D(64, (3, 3), activation='relu', padding='same'),
            MaxPooling2D(pool_size=(2, 2)),
            Flatten(),
            Dense(128, activation='relu'),
            Dense(1, activation='linear')
        ])
    },
    # Varying the number of filters per layer
    {
        'name': 'Less_Filters',
        'model': Sequential([
            Conv2D(16, (3, 3), activation='relu', padding='same', input_shape=(64, 64, 3)),
            MaxPooling2D(pool_size=(2, 2)),
            Conv2D(32, (3, 3), activation='relu', padding='same'),
            MaxPooling2D(pool_size=(2, 2)),
            Flatten(),
            Dense(128, activation='relu'),
            Dense(1, activation='linear')
        ])
    },
    {
        'name': 'More_Filters',
        'model': Sequential([
            Conv2D(64, (3, 3), activation='relu', padding='same', input_shape=(64, 64, 3)),
            MaxPooling2D(pool_size=(2, 2)),
            Conv2D(128, (3, 3), activation='relu', padding='same'),
            MaxPooling2D(pool_size=(2, 2)),
            Flatten(),
            Dense(128, activation='relu'),
            Dense(1, activation='linear')
        ])
    },
    # Varying activation functions
    # {
    #     'name': 'ReLU',
    #     'model': Sequential([
    #         Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(64, 64, 3)),
    #         MaxPooling2D(pool_size=(2, 2)),
    #         Conv2D(64, (3, 3), activation='relu', padding='same'),
    #         MaxPooling2D(pool_size=(2, 2)),
    #         Flatten(),
    #         Dense(128, activation='relu'),
    #         Dense(1, activation='linear')
    #     ])
    # },
    # {
    #     'name': 'Tanh',
    #     'model': Sequential([
    #         Conv2D(32, (3, 3), activation='tanh', padding='same', input_shape=(64, 64, 3)),
    #         MaxPooling2D(pool_size=(2, 2)),
    #         Conv2D(64, (3, 3), activation='tanh', padding='same'),
    #         MaxPooling2D(pool_size=(2, 2)),
    #         Flatten(),
    #         Dense(128, activation='tanh'),
    #         Dense(1, activation='linear')
    #     ])
    # },
    # Varying pooling operators
    {
        'name': 'MaxPooling',
        'model': Sequential([
            Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(64, 64, 3)),
            MaxPooling2D(pool_size=(2, 2)),
            Conv2D(64, (3, 3), activation='relu', padding='same'),
            MaxPooling2D(pool_size=(2, 2)),
            Flatten(),
            Dense(128, activation='relu'),
            Dense(1, activation='linear')
        ])
    },
    {
        'name': 'AvgPooling',
        'model': Sequential([
            Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(64, 64, 3)),
            tf.keras.layers.AvgPool2D(pool_size=(2, 2)),
            Conv2D(64, (3, 3), activation='relu', padding='same'),
            tf.keras.layers.AvgPool2D(pool_size=(2, 2)),
            Flatten(),
            Dense(128, activation='relu'),
            Dense(1, activation='linear')
        ])
    }
]

# Train and evaluate each architecture
results = []
for arch in architectures:
    print(f"Training {arch['name']} model...")
    model = arch['model']

    # Compile the model
    opt = Adam(learning_rate=1e-3, decay=1e-3 / 200)
    model.compile(loss="mean_absolute_percentage_error", optimizer=opt, metrics=['mean_absolute_percentage_error'])

    # Train the model
    history = model.fit(
        X_train, Y_train,
        validation_data=(X_val, Y_val),
        epochs=100,
        batch_size=32,
        verbose=1
    )
    prices_predicted = model.predict(X_val).flatten()
    diff = ((prices_predicted - Y_val) / Y_val) * 100
    error_mean = np.mean(np.abs(diff))

    print("Predicting house prices - Estimation Error: {:.2f}%".format(error_mean))

    # Save training and validation loss
    train_loss = history.history['mean_absolute_percentage_error'][-1]
    val_loss = history.history['val_mean_absolute_percentage_error'][-1]
    results.append({
        'name': arch['name'],
        'train_loss': train_loss,
        'val_loss': val_loss,
        'history': history.history
    })
    print(f"{arch['name']} - Train Loss: {train_loss:.4f}, Validation Loss: {val_loss:.4f}\n")

# Plot the results
architectures = [res['name'] for res in results]
train_losses = [res['train_loss'] for res in results]
val_losses = [res['val_loss'] for res in results]

x = range(len(architectures))
plt.bar(x, train_losses, width=0.4, label='Training Loss', align='center')
plt.bar(x, val_losses, width=0.4, label='Validation Loss', align='edge')
plt.xticks(x, architectures, rotation=45, ha='right')
plt.xlabel('Architectures')
plt.ylabel('Mean Absolute Percentage Error')
plt.title('Training and Validation Losses for Different Architectures')
plt.legend()
plt.tight_layout()
plt.show()

# Plot loss curves for the proposed architecture
proposed_model = min(results, key=lambda x: x['val_loss'])  # Select model with lowest validation loss
plt.figure(figsize=(10, 6))
plt.plot(proposed_model['history']['mean_absolute_percentage_error'], label='Training Loss')
plt.plot(proposed_model['history']['val_mean_absolute_percentage_error'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Mean Absolute Percentage Error')
plt.title(f"Loss Curves for Proposed Architecture ({proposed_model['name']})")
plt.legend()
plt.grid()
plt.tight_layout()
plt.show()

# model.summary()
# opt = Adam(lr=1e-3, decay=1e-3 / 200)
# model.compile(loss="mean_absolute_percentage_error", optimizer=opt, metrics=['mean_absolute_percentage_error'])

# # train the model
# print("[INFO] training model...")
# model.fit(X_train, Y_train, validation_data=(X_val, Y_val), epochs=100, batch_size=32)
# Out:
# X_train image shape: (428, 64, 64, 3)
# X_val image shape: (106, 64, 64, 3)
# Y_train labels shape: (428,)
# Y_val labels shape: (106,)
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Training Fewer_Conv_Layers model...
# /usr/local/lib/python3.10/dist-packages/keras/src/optimizers/base_optimizer.py:33: UserWarning: Argument `decay` is no longer supported and will be ignored.
#   warnings.warn(
# Epoch 1/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 5s 153ms/step - loss: 7084.1899 - mean_absolute_percentage_error: 7084.1899 - val_loss: 494.9649 - val_mean_absolute_percentage_error: 494.9649
# Epoch 2/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 809.8539 - mean_absolute_percentage_error: 809.8539 - val_loss: 324.3612 - val_mean_absolute_percentage_error: 324.3612
# Epoch 3/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 243.4025 - mean_absolute_percentage_error: 243.4025 - val_loss: 67.2169 - val_mean_absolute_percentage_error: 67.2169
# Epoch 4/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 79.0137 - mean_absolute_percentage_error: 79.0137 - val_loss: 60.9399 - val_mean_absolute_percentage_error: 60.9399
# Epoch 5/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 59.6971 - mean_absolute_percentage_error: 59.6971 - val_loss: 70.3657 - val_mean_absolute_percentage_error: 70.3657
# Epoch 6/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 54.7991 - mean_absolute_percentage_error: 54.7991 - val_loss: 56.6094 - val_mean_absolute_percentage_error: 56.6094
# Epoch 7/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 51.4198 - mean_absolute_percentage_error: 51.4198 - val_loss: 61.3968 - val_mean_absolute_percentage_error: 61.3968
# Epoch 8/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 44.3740 - mean_absolute_percentage_error: 44.3740 - val_loss: 67.8507 - val_mean_absolute_percentage_error: 67.8507
# Epoch 9/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 41.2844 - mean_absolute_percentage_error: 41.2844 - val_loss: 62.4330 - val_mean_absolute_percentage_error: 62.4330
# Epoch 10/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 39.3041 - mean_absolute_percentage_error: 39.3041 - val_loss: 62.9951 - val_mean_absolute_percentage_error: 62.9951
# Epoch 11/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 31.6757 - mean_absolute_percentage_error: 31.6757 - val_loss: 59.3016 - val_mean_absolute_percentage_error: 59.3016
# Epoch 12/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 37.8988 - mean_absolute_percentage_error: 37.8988 - val_loss: 64.4750 - val_mean_absolute_percentage_error: 64.4750
# Epoch 13/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 36.6076 - mean_absolute_percentage_error: 36.6076 - val_loss: 69.4389 - val_mean_absolute_percentage_error: 69.4389
# Epoch 14/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 34.1961 - mean_absolute_percentage_error: 34.1961 - val_loss: 60.6619 - val_mean_absolute_percentage_error: 60.6619
# Epoch 15/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 37.9541 - mean_absolute_percentage_error: 37.9541 - val_loss: 68.4330 - val_mean_absolute_percentage_error: 68.4330
# Epoch 16/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 31.8248 - mean_absolute_percentage_error: 31.8248 - val_loss: 71.3966 - val_mean_absolute_percentage_error: 71.3966
# Epoch 17/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 28.6480 - mean_absolute_percentage_error: 28.6480 - val_loss: 70.3776 - val_mean_absolute_percentage_error: 70.3776
# Epoch 18/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 30.9520 - mean_absolute_percentage_error: 30.9520 - val_loss: 71.1764 - val_mean_absolute_percentage_error: 71.1764
# Epoch 19/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 33.4040 - mean_absolute_percentage_error: 33.4040 - val_loss: 68.6199 - val_mean_absolute_percentage_error: 68.6199
# Epoch 20/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 27.6219 - mean_absolute_percentage_error: 27.6219 - val_loss: 64.7924 - val_mean_absolute_percentage_error: 64.7924
# Epoch 21/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 32.9016 - mean_absolute_percentage_error: 32.9016 - val_loss: 66.5279 - val_mean_absolute_percentage_error: 66.5279
# Epoch 22/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 33.2533 - mean_absolute_percentage_error: 33.2533 - val_loss: 74.6499 - val_mean_absolute_percentage_error: 74.6499
# Epoch 23/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 32.7126 - mean_absolute_percentage_error: 32.7126 - val_loss: 65.4645 - val_mean_absolute_percentage_error: 65.4645
# Epoch 24/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 35.5609 - mean_absolute_percentage_error: 35.5609 - val_loss: 73.4807 - val_mean_absolute_percentage_error: 73.4807
# Epoch 25/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 29.7428 - mean_absolute_percentage_error: 29.7428 - val_loss: 68.2029 - val_mean_absolute_percentage_error: 68.2029
# Epoch 26/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 28.2743 - mean_absolute_percentage_error: 28.2743 - val_loss: 72.2461 - val_mean_absolute_percentage_error: 72.2461
# Epoch 27/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 24.9705 - mean_absolute_percentage_error: 24.9705 - val_loss: 73.8338 - val_mean_absolute_percentage_error: 73.8338
# Epoch 28/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 24.5051 - mean_absolute_percentage_error: 24.5051 - val_loss: 68.0033 - val_mean_absolute_percentage_error: 68.0033
# Epoch 29/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 28.4771 - mean_absolute_percentage_error: 28.4771 - val_loss: 81.3347 - val_mean_absolute_percentage_error: 81.3347
# Epoch 30/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 27.5593 - mean_absolute_percentage_error: 27.5593 - val_loss: 70.9118 - val_mean_absolute_percentage_error: 70.9118
# Epoch 31/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 24.4738 - mean_absolute_percentage_error: 24.4738 - val_loss: 66.4633 - val_mean_absolute_percentage_error: 66.4633
# Epoch 32/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 30.1105 - mean_absolute_percentage_error: 30.1105 - val_loss: 87.7805 - val_mean_absolute_percentage_error: 87.7805
# Epoch 33/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 31.3349 - mean_absolute_percentage_error: 31.3349 - val_loss: 75.6890 - val_mean_absolute_percentage_error: 75.6890
# Epoch 34/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 24.3147 - mean_absolute_percentage_error: 24.3147 - val_loss: 78.0265 - val_mean_absolute_percentage_error: 78.0265
# Epoch 35/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 23.6323 - mean_absolute_percentage_error: 23.6323 - val_loss: 72.3045 - val_mean_absolute_percentage_error: 72.3045
# Epoch 36/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 23.5090 - mean_absolute_percentage_error: 23.5090 - val_loss: 73.7255 - val_mean_absolute_percentage_error: 73.7255
# Epoch 37/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 21.0617 - mean_absolute_percentage_error: 21.0617 - val_loss: 75.0404 - val_mean_absolute_percentage_error: 75.0404
# Epoch 38/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 21.8819 - mean_absolute_percentage_error: 21.8819 - val_loss: 83.9177 - val_mean_absolute_percentage_error: 83.9177
# Epoch 39/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 27.9166 - mean_absolute_percentage_error: 27.9166 - val_loss: 78.4521 - val_mean_absolute_percentage_error: 78.4521
# Epoch 40/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 26.8243 - mean_absolute_percentage_error: 26.8243 - val_loss: 79.5819 - val_mean_absolute_percentage_error: 79.5819
# Epoch 41/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 26.1238 - mean_absolute_percentage_error: 26.1238 - val_loss: 71.3577 - val_mean_absolute_percentage_error: 71.3577
# Epoch 42/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 22.0988 - mean_absolute_percentage_error: 22.0988 - val_loss: 73.1299 - val_mean_absolute_percentage_error: 73.1299
# Epoch 43/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 20.6993 - mean_absolute_percentage_error: 20.6993 - val_loss: 72.1861 - val_mean_absolute_percentage_error: 72.1861
# Epoch 44/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 22.4106 - mean_absolute_percentage_error: 22.4106 - val_loss: 75.5509 - val_mean_absolute_percentage_error: 75.5509
# Epoch 45/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 22.5127 - mean_absolute_percentage_error: 22.5127 - val_loss: 78.7877 - val_mean_absolute_percentage_error: 78.7877
# Epoch 46/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 23.2809 - mean_absolute_percentage_error: 23.2809 - val_loss: 71.0608 - val_mean_absolute_percentage_error: 71.0608
# Epoch 47/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 22.2110 - mean_absolute_percentage_error: 22.2110 - val_loss: 83.5279 - val_mean_absolute_percentage_error: 83.5279
# Epoch 48/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 23.3272 - mean_absolute_percentage_error: 23.3272 - val_loss: 71.3387 - val_mean_absolute_percentage_error: 71.3387
# Epoch 49/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 24.7671 - mean_absolute_percentage_error: 24.7671 - val_loss: 80.9411 - val_mean_absolute_percentage_error: 80.9411
# Epoch 50/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 23.2242 - mean_absolute_percentage_error: 23.2242 - val_loss: 79.9117 - val_mean_absolute_percentage_error: 79.9117
# Epoch 51/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 18.6012 - mean_absolute_percentage_error: 18.6012 - val_loss: 74.8595 - val_mean_absolute_percentage_error: 74.8595
# Epoch 52/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 22.1306 - mean_absolute_percentage_error: 22.1306 - val_loss: 79.5650 - val_mean_absolute_percentage_error: 79.5650
# Epoch 53/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 27.3504 - mean_absolute_percentage_error: 27.3504 - val_loss: 73.3314 - val_mean_absolute_percentage_error: 73.3314
# Epoch 54/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 22.5068 - mean_absolute_percentage_error: 22.5068 - val_loss: 81.9075 - val_mean_absolute_percentage_error: 81.9075
# Epoch 55/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 21.9046 - mean_absolute_percentage_error: 21.9046 - val_loss: 86.2434 - val_mean_absolute_percentage_error: 86.2434
# Epoch 56/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 22.2423 - mean_absolute_percentage_error: 22.2423 - val_loss: 75.6194 - val_mean_absolute_percentage_error: 75.6194
# Epoch 57/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 20.2556 - mean_absolute_percentage_error: 20.2556 - val_loss: 82.3374 - val_mean_absolute_percentage_error: 82.3374
# Epoch 58/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 19.9167 - mean_absolute_percentage_error: 19.9167 - val_loss: 74.5203 - val_mean_absolute_percentage_error: 74.5203
# Epoch 59/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 22.6762 - mean_absolute_percentage_error: 22.6762 - val_loss: 82.8879 - val_mean_absolute_percentage_error: 82.8879
# Epoch 60/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 21.3537 - mean_absolute_percentage_error: 21.3537 - val_loss: 67.7859 - val_mean_absolute_percentage_error: 67.7859
# Epoch 61/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 32.9951 - mean_absolute_percentage_error: 32.9951 - val_loss: 70.8294 - val_mean_absolute_percentage_error: 70.8294
# Epoch 62/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 31.1775 - mean_absolute_percentage_error: 31.1775 - val_loss: 71.9107 - val_mean_absolute_percentage_error: 71.9107
# Epoch 63/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 26.8453 - mean_absolute_percentage_error: 26.8453 - val_loss: 86.1284 - val_mean_absolute_percentage_error: 86.1284
# Epoch 64/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 25.3161 - mean_absolute_percentage_error: 25.3161 - val_loss: 76.8448 - val_mean_absolute_percentage_error: 76.8448
# Epoch 65/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 22.7919 - mean_absolute_percentage_error: 22.7919 - val_loss: 73.5993 - val_mean_absolute_percentage_error: 73.5993
# Epoch 66/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 25.6818 - mean_absolute_percentage_error: 25.6818 - val_loss: 82.8932 - val_mean_absolute_percentage_error: 82.8932
# Epoch 67/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 21.2349 - mean_absolute_percentage_error: 21.2349 - val_loss: 76.9093 - val_mean_absolute_percentage_error: 76.9093
# Epoch 68/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 19.2810 - mean_absolute_percentage_error: 19.2810 - val_loss: 79.3429 - val_mean_absolute_percentage_error: 79.3429
# Epoch 69/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 17.7092 - mean_absolute_percentage_error: 17.7092 - val_loss: 78.3607 - val_mean_absolute_percentage_error: 78.3607
# Epoch 70/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 14.6102 - mean_absolute_percentage_error: 14.6102 - val_loss: 76.7419 - val_mean_absolute_percentage_error: 76.7419
# Epoch 71/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 18.1336 - mean_absolute_percentage_error: 18.1336 - val_loss: 85.2837 - val_mean_absolute_percentage_error: 85.2837
# Epoch 72/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 19.4286 - mean_absolute_percentage_error: 19.4286 - val_loss: 72.2459 - val_mean_absolute_percentage_error: 72.2459
# Epoch 73/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 20.5875 - mean_absolute_percentage_error: 20.5875 - val_loss: 80.7864 - val_mean_absolute_percentage_error: 80.7864
# Epoch 74/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 20.6966 - mean_absolute_percentage_error: 20.6966 - val_loss: 81.0827 - val_mean_absolute_percentage_error: 81.0827
# Epoch 75/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 20.3436 - mean_absolute_percentage_error: 20.3436 - val_loss: 80.9580 - val_mean_absolute_percentage_error: 80.9580
# Epoch 76/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 18.0683 - mean_absolute_percentage_error: 18.0683 - val_loss: 81.6246 - val_mean_absolute_percentage_error: 81.6246
# Epoch 77/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 19.5597 - mean_absolute_percentage_error: 19.5597 - val_loss: 76.9116 - val_mean_absolute_percentage_error: 76.9116
# Epoch 78/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 17.4663 - mean_absolute_percentage_error: 17.4663 - val_loss: 87.0388 - val_mean_absolute_percentage_error: 87.0388
# Epoch 79/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 20.3567 - mean_absolute_percentage_error: 20.3567 - val_loss: 78.8724 - val_mean_absolute_percentage_error: 78.8724
# Epoch 80/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 16.1139 - mean_absolute_percentage_error: 16.1139 - val_loss: 82.2384 - val_mean_absolute_percentage_error: 82.2384
# Epoch 81/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 17.0272 - mean_absolute_percentage_error: 17.0272 - val_loss: 80.1494 - val_mean_absolute_percentage_error: 80.1494
# Epoch 82/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 19.8605 - mean_absolute_percentage_error: 19.8605 - val_loss: 81.1786 - val_mean_absolute_percentage_error: 81.1786
# Epoch 83/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 17.7613 - mean_absolute_percentage_error: 17.7613 - val_loss: 79.7455 - val_mean_absolute_percentage_error: 79.7455
# Epoch 84/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 17.9801 - mean_absolute_percentage_error: 17.9801 - val_loss: 71.8744 - val_mean_absolute_percentage_error: 71.8744
# Epoch 85/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 24.7648 - mean_absolute_percentage_error: 24.7648 - val_loss: 82.5081 - val_mean_absolute_percentage_error: 82.5081
# Epoch 86/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 22.1002 - mean_absolute_percentage_error: 22.1002 - val_loss: 80.5256 - val_mean_absolute_percentage_error: 80.5256
# Epoch 87/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 23.7708 - mean_absolute_percentage_error: 23.7708 - val_loss: 79.9775 - val_mean_absolute_percentage_error: 79.9775
# Epoch 88/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 14.3623 - mean_absolute_percentage_error: 14.3623 - val_loss: 87.8869 - val_mean_absolute_percentage_error: 87.8869
# Epoch 89/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 27.5315 - mean_absolute_percentage_error: 27.5315 - val_loss: 76.5899 - val_mean_absolute_percentage_error: 76.5899
# Epoch 90/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 18.6757 - mean_absolute_percentage_error: 18.6757 - val_loss: 81.9101 - val_mean_absolute_percentage_error: 81.9101
# Epoch 91/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 18.5198 - mean_absolute_percentage_error: 18.5198 - val_loss: 81.2966 - val_mean_absolute_percentage_error: 81.2966
# Epoch 92/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 16.1464 - mean_absolute_percentage_error: 16.1464 - val_loss: 81.2541 - val_mean_absolute_percentage_error: 81.2541
# Epoch 93/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 17.8869 - mean_absolute_percentage_error: 17.8869 - val_loss: 77.6560 - val_mean_absolute_percentage_error: 77.6560
# Epoch 94/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 18.6235 - mean_absolute_percentage_error: 18.6235 - val_loss: 81.3595 - val_mean_absolute_percentage_error: 81.3595
# Epoch 95/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 22.9072 - mean_absolute_percentage_error: 22.9072 - val_loss: 77.7406 - val_mean_absolute_percentage_error: 77.7406
# Epoch 96/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 22.1437 - mean_absolute_percentage_error: 22.1437 - val_loss: 76.5731 - val_mean_absolute_percentage_error: 76.5731
# Epoch 97/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 20.7389 - mean_absolute_percentage_error: 20.7389 - val_loss: 89.8978 - val_mean_absolute_percentage_error: 89.8978
# Epoch 98/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 20.9007 - mean_absolute_percentage_error: 20.9007 - val_loss: 75.9760 - val_mean_absolute_percentage_error: 75.9760
# Epoch 99/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 19.5409 - mean_absolute_percentage_error: 19.5409 - val_loss: 78.0131 - val_mean_absolute_percentage_error: 78.0131
# Epoch 100/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 15.7389 - mean_absolute_percentage_error: 15.7389 - val_loss: 82.8981 - val_mean_absolute_percentage_error: 82.8981
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# Predicting house prices - Estimation Error: 82.90%
# Fewer_Conv_Layers - Train Loss: 18.6603, Validation Loss: 82.8981
#
# Training More_Conv_Layers model...
# Epoch 1/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 5s 167ms/step - loss: 1968.8767 - mean_absolute_percentage_error: 1968.8767 - val_loss: 60.7583 - val_mean_absolute_percentage_error: 60.7583
# Epoch 2/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 65.3420 - mean_absolute_percentage_error: 65.3420 - val_loss: 60.6668 - val_mean_absolute_percentage_error: 60.6668
# Epoch 3/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 64.7608 - mean_absolute_percentage_error: 64.7608 - val_loss: 58.5554 - val_mean_absolute_percentage_error: 58.5554
# Epoch 4/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 60.7890 - mean_absolute_percentage_error: 60.7890 - val_loss: 56.9215 - val_mean_absolute_percentage_error: 56.9215
# Epoch 5/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 52.1565 - mean_absolute_percentage_error: 52.1565 - val_loss: 59.3867 - val_mean_absolute_percentage_error: 59.3867
# Epoch 6/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 53.0090 - mean_absolute_percentage_error: 53.0090 - val_loss: 55.9993 - val_mean_absolute_percentage_error: 55.9993
# Epoch 7/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 47.2664 - mean_absolute_percentage_error: 47.2664 - val_loss: 57.4420 - val_mean_absolute_percentage_error: 57.4420
# Epoch 8/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 46.5846 - mean_absolute_percentage_error: 46.5846 - val_loss: 55.2400 - val_mean_absolute_percentage_error: 55.2400
# Epoch 9/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 43.4718 - mean_absolute_percentage_error: 43.4718 - val_loss: 51.1257 - val_mean_absolute_percentage_error: 51.1257
# Epoch 10/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 41.9976 - mean_absolute_percentage_error: 41.9976 - val_loss: 53.9374 - val_mean_absolute_percentage_error: 53.9374
# Epoch 11/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 38.3855 - mean_absolute_percentage_error: 38.3855 - val_loss: 52.6598 - val_mean_absolute_percentage_error: 52.6598
# Epoch 12/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 40.2913 - mean_absolute_percentage_error: 40.2913 - val_loss: 54.3454 - val_mean_absolute_percentage_error: 54.3454
# Epoch 13/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 32.9604 - mean_absolute_percentage_error: 32.9604 - val_loss: 65.1608 - val_mean_absolute_percentage_error: 65.1608
# Epoch 14/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 37.2593 - mean_absolute_percentage_error: 37.2593 - val_loss: 55.6384 - val_mean_absolute_percentage_error: 55.6384
# Epoch 15/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 32.7805 - mean_absolute_percentage_error: 32.7805 - val_loss: 58.2331 - val_mean_absolute_percentage_error: 58.2331
# Epoch 16/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 34.5132 - mean_absolute_percentage_error: 34.5132 - val_loss: 55.2004 - val_mean_absolute_percentage_error: 55.2004
# Epoch 17/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 31.4496 - mean_absolute_percentage_error: 31.4496 - val_loss: 56.9650 - val_mean_absolute_percentage_error: 56.9650
# Epoch 18/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 31.0693 - mean_absolute_percentage_error: 31.0693 - val_loss: 53.5985 - val_mean_absolute_percentage_error: 53.5985
# Epoch 19/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 29.6015 - mean_absolute_percentage_error: 29.6015 - val_loss: 52.3825 - val_mean_absolute_percentage_error: 52.3825
# Epoch 20/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 33.4076 - mean_absolute_percentage_error: 33.4076 - val_loss: 56.8090 - val_mean_absolute_percentage_error: 56.8090
# Epoch 21/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 32.6201 - mean_absolute_percentage_error: 32.6201 - val_loss: 56.1343 - val_mean_absolute_percentage_error: 56.1343
# Epoch 22/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 31.8034 - mean_absolute_percentage_error: 31.8034 - val_loss: 59.2939 - val_mean_absolute_percentage_error: 59.2939
# Epoch 23/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 37.3994 - mean_absolute_percentage_error: 37.3994 - val_loss: 52.2287 - val_mean_absolute_percentage_error: 52.2287
# Epoch 24/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 28.1523 - mean_absolute_percentage_error: 28.1523 - val_loss: 61.3000 - val_mean_absolute_percentage_error: 61.3000
# Epoch 25/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 33.9798 - mean_absolute_percentage_error: 33.9798 - val_loss: 54.0174 - val_mean_absolute_percentage_error: 54.0174
# Epoch 26/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 28.1437 - mean_absolute_percentage_error: 28.1437 - val_loss: 56.4963 - val_mean_absolute_percentage_error: 56.4963
# Epoch 27/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 26.4173 - mean_absolute_percentage_error: 26.4173 - val_loss: 57.1434 - val_mean_absolute_percentage_error: 57.1434
# Epoch 28/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 27.1280 - mean_absolute_percentage_error: 27.1280 - val_loss: 56.2377 - val_mean_absolute_percentage_error: 56.2377
# Epoch 29/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 27.6688 - mean_absolute_percentage_error: 27.6688 - val_loss: 57.9349 - val_mean_absolute_percentage_error: 57.9349
# Epoch 30/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 24.0068 - mean_absolute_percentage_error: 24.0068 - val_loss: 54.2990 - val_mean_absolute_percentage_error: 54.2990
# Epoch 31/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 26.4451 - mean_absolute_percentage_error: 26.4451 - val_loss: 53.0334 - val_mean_absolute_percentage_error: 53.0334
# Epoch 32/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 29.2582 - mean_absolute_percentage_error: 29.2582 - val_loss: 60.7291 - val_mean_absolute_percentage_error: 60.7291
# Epoch 33/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 22.9121 - mean_absolute_percentage_error: 22.9121 - val_loss: 61.3706 - val_mean_absolute_percentage_error: 61.3706
# Epoch 34/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 23.5137 - mean_absolute_percentage_error: 23.5137 - val_loss: 53.6862 - val_mean_absolute_percentage_error: 53.6862
# Epoch 35/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 28.6451 - mean_absolute_percentage_error: 28.6451 - val_loss: 58.3799 - val_mean_absolute_percentage_error: 58.3799
# Epoch 36/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 24.5165 - mean_absolute_percentage_error: 24.5165 - val_loss: 55.3701 - val_mean_absolute_percentage_error: 55.3701
# Epoch 37/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 22.6791 - mean_absolute_percentage_error: 22.6791 - val_loss: 55.4394 - val_mean_absolute_percentage_error: 55.4394
# Epoch 38/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 21.3790 - mean_absolute_percentage_error: 21.3790 - val_loss: 55.6534 - val_mean_absolute_percentage_error: 55.6534
# Epoch 39/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 22.9770 - mean_absolute_percentage_error: 22.9770 - val_loss: 62.5239 - val_mean_absolute_percentage_error: 62.5239
# Epoch 40/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 21.0197 - mean_absolute_percentage_error: 21.0197 - val_loss: 57.1003 - val_mean_absolute_percentage_error: 57.1003
# Epoch 41/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 19.3195 - mean_absolute_percentage_error: 19.3195 - val_loss: 67.1530 - val_mean_absolute_percentage_error: 67.1530
# Epoch 42/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 19.9595 - mean_absolute_percentage_error: 19.9595 - val_loss: 61.6566 - val_mean_absolute_percentage_error: 61.6566
# Epoch 43/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 19.3682 - mean_absolute_percentage_error: 19.3682 - val_loss: 60.3507 - val_mean_absolute_percentage_error: 60.3507
# Epoch 44/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 17.0454 - mean_absolute_percentage_error: 17.0454 - val_loss: 60.8866 - val_mean_absolute_percentage_error: 60.8866
# Epoch 45/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 17.5254 - mean_absolute_percentage_error: 17.5254 - val_loss: 57.8477 - val_mean_absolute_percentage_error: 57.8477
# Epoch 46/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 23.3567 - mean_absolute_percentage_error: 23.3567 - val_loss: 68.6934 - val_mean_absolute_percentage_error: 68.6934
# Epoch 47/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 21.0432 - mean_absolute_percentage_error: 21.0432 - val_loss: 56.5976 - val_mean_absolute_percentage_error: 56.5976
# Epoch 48/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 23.2236 - mean_absolute_percentage_error: 23.2236 - val_loss: 63.1145 - val_mean_absolute_percentage_error: 63.1145
# Epoch 49/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 21.5248 - mean_absolute_percentage_error: 21.5248 - val_loss: 63.8059 - val_mean_absolute_percentage_error: 63.8059
# Epoch 50/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 18.1669 - mean_absolute_percentage_error: 18.1669 - val_loss: 61.0834 - val_mean_absolute_percentage_error: 61.0834
# Epoch 51/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 18.0778 - mean_absolute_percentage_error: 18.0778 - val_loss: 61.1115 - val_mean_absolute_percentage_error: 61.1115
# Epoch 52/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 17.9058 - mean_absolute_percentage_error: 17.9058 - val_loss: 61.5088 - val_mean_absolute_percentage_error: 61.5088
# Epoch 53/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 17.1544 - mean_absolute_percentage_error: 17.1544 - val_loss: 64.0887 - val_mean_absolute_percentage_error: 64.0887
# Epoch 54/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 18.8666 - mean_absolute_percentage_error: 18.8666 - val_loss: 60.9279 - val_mean_absolute_percentage_error: 60.9279
# Epoch 55/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 16.1275 - mean_absolute_percentage_error: 16.1275 - val_loss: 62.1109 - val_mean_absolute_percentage_error: 62.1109
# Epoch 56/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 16.5683 - mean_absolute_percentage_error: 16.5683 - val_loss: 62.3092 - val_mean_absolute_percentage_error: 62.3092
# Epoch 57/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 15.5691 - mean_absolute_percentage_error: 15.5691 - val_loss: 67.0072 - val_mean_absolute_percentage_error: 67.0072
# Epoch 58/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 16.7929 - mean_absolute_percentage_error: 16.7929 - val_loss: 68.7046 - val_mean_absolute_percentage_error: 68.7046
# Epoch 59/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 15.6803 - mean_absolute_percentage_error: 15.6803 - val_loss: 65.3825 - val_mean_absolute_percentage_error: 65.3825
# Epoch 60/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 14.9698 - mean_absolute_percentage_error: 14.9698 - val_loss: 76.1611 - val_mean_absolute_percentage_error: 76.1611
# Epoch 61/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 18.8411 - mean_absolute_percentage_error: 18.8411 - val_loss: 60.1737 - val_mean_absolute_percentage_error: 60.1737
# Epoch 62/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 18.4804 - mean_absolute_percentage_error: 18.4804 - val_loss: 63.2437 - val_mean_absolute_percentage_error: 63.2437
# Epoch 63/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 15.1571 - mean_absolute_percentage_error: 15.1571 - val_loss: 67.8301 - val_mean_absolute_percentage_error: 67.8301
# Epoch 64/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 14.8078 - mean_absolute_percentage_error: 14.8078 - val_loss: 64.9868 - val_mean_absolute_percentage_error: 64.9868
# Epoch 65/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 13.5628 - mean_absolute_percentage_error: 13.5628 - val_loss: 63.6482 - val_mean_absolute_percentage_error: 63.6482
# Epoch 66/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 15.1594 - mean_absolute_percentage_error: 15.1594 - val_loss: 65.4860 - val_mean_absolute_percentage_error: 65.4860
# Epoch 67/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 13.6935 - mean_absolute_percentage_error: 13.6935 - val_loss: 66.4275 - val_mean_absolute_percentage_error: 66.4275
# Epoch 68/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 15.5633 - mean_absolute_percentage_error: 15.5633 - val_loss: 66.9768 - val_mean_absolute_percentage_error: 66.9768
# Epoch 69/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 16.1983 - mean_absolute_percentage_error: 16.1983 - val_loss: 64.4681 - val_mean_absolute_percentage_error: 64.4681
# Epoch 70/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 15.1135 - mean_absolute_percentage_error: 15.1135 - val_loss: 63.9996 - val_mean_absolute_percentage_error: 63.9996
# Epoch 71/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 14.9397 - mean_absolute_percentage_error: 14.9397 - val_loss: 64.5935 - val_mean_absolute_percentage_error: 64.5935
# Epoch 72/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 14.7822 - mean_absolute_percentage_error: 14.7822 - val_loss: 67.4312 - val_mean_absolute_percentage_error: 67.4312
# Epoch 73/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 14.3122 - mean_absolute_percentage_error: 14.3122 - val_loss: 64.9625 - val_mean_absolute_percentage_error: 64.9625
# Epoch 74/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 16.2827 - mean_absolute_percentage_error: 16.2827 - val_loss: 66.5775 - val_mean_absolute_percentage_error: 66.5775
# Epoch 75/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 16.3325 - mean_absolute_percentage_error: 16.3325 - val_loss: 69.4292 - val_mean_absolute_percentage_error: 69.4292
# Epoch 76/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 15.4094 - mean_absolute_percentage_error: 15.4094 - val_loss: 68.9222 - val_mean_absolute_percentage_error: 68.9222
# Epoch 77/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 13.7694 - mean_absolute_percentage_error: 13.7694 - val_loss: 64.4107 - val_mean_absolute_percentage_error: 64.4107
# Epoch 78/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 12.2314 - mean_absolute_percentage_error: 12.2314 - val_loss: 70.9366 - val_mean_absolute_percentage_error: 70.9366
# Epoch 79/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 13.5636 - mean_absolute_percentage_error: 13.5636 - val_loss: 64.6397 - val_mean_absolute_percentage_error: 64.6397
# Epoch 80/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 13.0753 - mean_absolute_percentage_error: 13.0753 - val_loss: 70.4124 - val_mean_absolute_percentage_error: 70.4124
# Epoch 81/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 11.6841 - mean_absolute_percentage_error: 11.6841 - val_loss: 72.5023 - val_mean_absolute_percentage_error: 72.5023
# Epoch 82/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 13.5331 - mean_absolute_percentage_error: 13.5331 - val_loss: 64.0130 - val_mean_absolute_percentage_error: 64.0130
# Epoch 83/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 12.3432 - mean_absolute_percentage_error: 12.3432 - val_loss: 68.5594 - val_mean_absolute_percentage_error: 68.5594
# Epoch 84/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 12.6620 - mean_absolute_percentage_error: 12.6620 - val_loss: 69.7400 - val_mean_absolute_percentage_error: 69.7400
# Epoch 85/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 12.9827 - mean_absolute_percentage_error: 12.9827 - val_loss: 65.5514 - val_mean_absolute_percentage_error: 65.5514
# Epoch 86/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 11.3038 - mean_absolute_percentage_error: 11.3038 - val_loss: 73.0288 - val_mean_absolute_percentage_error: 73.0288
# Epoch 87/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 13.0402 - mean_absolute_percentage_error: 13.0402 - val_loss: 70.3606 - val_mean_absolute_percentage_error: 70.3606
# Epoch 88/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 13.2193 - mean_absolute_percentage_error: 13.2193 - val_loss: 69.2633 - val_mean_absolute_percentage_error: 69.2633
# Epoch 89/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 12.9968 - mean_absolute_percentage_error: 12.9968 - val_loss: 71.7333 - val_mean_absolute_percentage_error: 71.7333
# Epoch 90/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 13.4542 - mean_absolute_percentage_error: 13.4542 - val_loss: 67.5751 - val_mean_absolute_percentage_error: 67.5751
# Epoch 91/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 10.9988 - mean_absolute_percentage_error: 10.9988 - val_loss: 79.1393 - val_mean_absolute_percentage_error: 79.1393
# Epoch 92/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 15.3596 - mean_absolute_percentage_error: 15.3596 - val_loss: 76.7893 - val_mean_absolute_percentage_error: 76.7893
# Epoch 93/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 15.0019 - mean_absolute_percentage_error: 15.0019 - val_loss: 67.3561 - val_mean_absolute_percentage_error: 67.3561
# Epoch 94/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 15.0484 - mean_absolute_percentage_error: 15.0484 - val_loss: 69.2203 - val_mean_absolute_percentage_error: 69.2203
# Epoch 95/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 14.4607 - mean_absolute_percentage_error: 14.4607 - val_loss: 61.8235 - val_mean_absolute_percentage_error: 61.8235
# Epoch 96/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 12.9847 - mean_absolute_percentage_error: 12.9847 - val_loss: 71.7849 - val_mean_absolute_percentage_error: 71.7849
# Epoch 97/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 14.4322 - mean_absolute_percentage_error: 14.4322 - val_loss: 70.1637 - val_mean_absolute_percentage_error: 70.1637
# Epoch 98/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 12.3630 - mean_absolute_percentage_error: 12.3630 - val_loss: 66.1040 - val_mean_absolute_percentage_error: 66.1040
# Epoch 99/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 10.8652 - mean_absolute_percentage_error: 10.8652 - val_loss: 69.6810 - val_mean_absolute_percentage_error: 69.6810
# Epoch 100/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 11.6609 - mean_absolute_percentage_error: 11.6609 - val_loss: 68.0673 - val_mean_absolute_percentage_error: 68.0673
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# Predicting house prices - Estimation Error: 68.07%
# More_Conv_Layers - Train Loss: 10.9875, Validation Loss: 68.0673
#
# Training Less_Filters model...
# Epoch 1/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 5s 167ms/step - loss: 1313.4073 - mean_absolute_percentage_error: 1313.4073 - val_loss: 101.6375 - val_mean_absolute_percentage_error: 101.6375
# Epoch 2/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 112.8235 - mean_absolute_percentage_error: 112.8235 - val_loss: 67.2221 - val_mean_absolute_percentage_error: 67.2221
# Epoch 3/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 69.9593 - mean_absolute_percentage_error: 69.9593 - val_loss: 61.1062 - val_mean_absolute_percentage_error: 61.1062
# Epoch 4/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 62.9080 - mean_absolute_percentage_error: 62.9080 - val_loss: 60.2568 - val_mean_absolute_percentage_error: 60.2568
# Epoch 5/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 59.1125 - mean_absolute_percentage_error: 59.1125 - val_loss: 62.1290 - val_mean_absolute_percentage_error: 62.1290
# Epoch 6/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 54.3997 - mean_absolute_percentage_error: 54.3997 - val_loss: 58.9444 - val_mean_absolute_percentage_error: 58.9444
# Epoch 7/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 45.1159 - mean_absolute_percentage_error: 45.1159 - val_loss: 67.9217 - val_mean_absolute_percentage_error: 67.9217
# Epoch 8/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 53.1451 - mean_absolute_percentage_error: 53.1451 - val_loss: 63.8321 - val_mean_absolute_percentage_error: 63.8321
# Epoch 9/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 44.4357 - mean_absolute_percentage_error: 44.4357 - val_loss: 59.8463 - val_mean_absolute_percentage_error: 59.8463
# Epoch 10/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 44.3680 - mean_absolute_percentage_error: 44.3680 - val_loss: 57.2199 - val_mean_absolute_percentage_error: 57.2199
# Epoch 11/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 38.8184 - mean_absolute_percentage_error: 38.8184 - val_loss: 60.5105 - val_mean_absolute_percentage_error: 60.5105
# Epoch 12/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 38.1396 - mean_absolute_percentage_error: 38.1396 - val_loss: 61.0409 - val_mean_absolute_percentage_error: 61.0409
# Epoch 13/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 36.3803 - mean_absolute_percentage_error: 36.3803 - val_loss: 54.7988 - val_mean_absolute_percentage_error: 54.7988
# Epoch 14/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 35.2104 - mean_absolute_percentage_error: 35.2104 - val_loss: 62.1192 - val_mean_absolute_percentage_error: 62.1192
# Epoch 15/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 30.5903 - mean_absolute_percentage_error: 30.5903 - val_loss: 63.5173 - val_mean_absolute_percentage_error: 63.5173
# Epoch 16/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 31.6608 - mean_absolute_percentage_error: 31.6608 - val_loss: 57.2060 - val_mean_absolute_percentage_error: 57.2060
# Epoch 17/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 33.7075 - mean_absolute_percentage_error: 33.7075 - val_loss: 60.2894 - val_mean_absolute_percentage_error: 60.2894
# Epoch 18/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 28.6410 - mean_absolute_percentage_error: 28.6410 - val_loss: 61.6846 - val_mean_absolute_percentage_error: 61.6846
# Epoch 19/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 31.3685 - mean_absolute_percentage_error: 31.3685 - val_loss: 59.8823 - val_mean_absolute_percentage_error: 59.8823
# Epoch 20/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 29.6012 - mean_absolute_percentage_error: 29.6012 - val_loss: 53.6387 - val_mean_absolute_percentage_error: 53.6387
# Epoch 21/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 34.1105 - mean_absolute_percentage_error: 34.1105 - val_loss: 61.2930 - val_mean_absolute_percentage_error: 61.2930
# Epoch 22/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 31.6872 - mean_absolute_percentage_error: 31.6872 - val_loss: 61.0896 - val_mean_absolute_percentage_error: 61.0896
# Epoch 23/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 33.2644 - mean_absolute_percentage_error: 33.2644 - val_loss: 63.8678 - val_mean_absolute_percentage_error: 63.8678
# Epoch 24/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 28.9476 - mean_absolute_percentage_error: 28.9476 - val_loss: 57.6982 - val_mean_absolute_percentage_error: 57.6982
# Epoch 25/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 25.6373 - mean_absolute_percentage_error: 25.6373 - val_loss: 57.4490 - val_mean_absolute_percentage_error: 57.4490
# Epoch 26/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 29.1060 - mean_absolute_percentage_error: 29.1060 - val_loss: 60.7165 - val_mean_absolute_percentage_error: 60.7165
# Epoch 27/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 27.4371 - mean_absolute_percentage_error: 27.4371 - val_loss: 59.7241 - val_mean_absolute_percentage_error: 59.7241
# Epoch 28/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 25.3723 - mean_absolute_percentage_error: 25.3723 - val_loss: 61.2745 - val_mean_absolute_percentage_error: 61.2745
# Epoch 29/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 22.8258 - mean_absolute_percentage_error: 22.8258 - val_loss: 70.1488 - val_mean_absolute_percentage_error: 70.1488
# Epoch 30/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 31.0515 - mean_absolute_percentage_error: 31.0515 - val_loss: 65.9765 - val_mean_absolute_percentage_error: 65.9765
# Epoch 31/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 25.9593 - mean_absolute_percentage_error: 25.9593 - val_loss: 58.6571 - val_mean_absolute_percentage_error: 58.6571
# Epoch 32/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 24.4355 - mean_absolute_percentage_error: 24.4355 - val_loss: 57.1225 - val_mean_absolute_percentage_error: 57.1225
# Epoch 33/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 23.2486 - mean_absolute_percentage_error: 23.2486 - val_loss: 63.9109 - val_mean_absolute_percentage_error: 63.9109
# Epoch 34/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 20.9798 - mean_absolute_percentage_error: 20.9798 - val_loss: 58.6358 - val_mean_absolute_percentage_error: 58.6358
# Epoch 35/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 22.9831 - mean_absolute_percentage_error: 22.9831 - val_loss: 64.9287 - val_mean_absolute_percentage_error: 64.9287
# Epoch 36/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 24.2513 - mean_absolute_percentage_error: 24.2513 - val_loss: 64.1271 - val_mean_absolute_percentage_error: 64.1271
# Epoch 37/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 22.5624 - mean_absolute_percentage_error: 22.5624 - val_loss: 61.7669 - val_mean_absolute_percentage_error: 61.7669
# Epoch 38/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 23.1574 - mean_absolute_percentage_error: 23.1574 - val_loss: 59.4497 - val_mean_absolute_percentage_error: 59.4497
# Epoch 39/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 20.3301 - mean_absolute_percentage_error: 20.3301 - val_loss: 59.4363 - val_mean_absolute_percentage_error: 59.4363
# Epoch 40/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 18.4236 - mean_absolute_percentage_error: 18.4236 - val_loss: 65.3208 - val_mean_absolute_percentage_error: 65.3208
# Epoch 41/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 23.4393 - mean_absolute_percentage_error: 23.4393 - val_loss: 56.2902 - val_mean_absolute_percentage_error: 56.2902
# Epoch 42/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 25.3481 - mean_absolute_percentage_error: 25.3481 - val_loss: 56.9340 - val_mean_absolute_percentage_error: 56.9340
# Epoch 43/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 23.9001 - mean_absolute_percentage_error: 23.9001 - val_loss: 60.3601 - val_mean_absolute_percentage_error: 60.3601
# Epoch 44/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 21.0970 - mean_absolute_percentage_error: 21.0970 - val_loss: 64.9489 - val_mean_absolute_percentage_error: 64.9489
# Epoch 45/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 20.7711 - mean_absolute_percentage_error: 20.7711 - val_loss: 62.6034 - val_mean_absolute_percentage_error: 62.6034
# Epoch 46/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 17.7359 - mean_absolute_percentage_error: 17.7359 - val_loss: 62.3096 - val_mean_absolute_percentage_error: 62.3096
# Epoch 47/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 18.1540 - mean_absolute_percentage_error: 18.1540 - val_loss: 62.9084 - val_mean_absolute_percentage_error: 62.9084
# Epoch 48/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 19.6866 - mean_absolute_percentage_error: 19.6866 - val_loss: 61.0610 - val_mean_absolute_percentage_error: 61.0610
# Epoch 49/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 16.7399 - mean_absolute_percentage_error: 16.7399 - val_loss: 62.6862 - val_mean_absolute_percentage_error: 62.6862
# Epoch 50/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 15.6713 - mean_absolute_percentage_error: 15.6713 - val_loss: 62.4109 - val_mean_absolute_percentage_error: 62.4109
# Epoch 51/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 15.8664 - mean_absolute_percentage_error: 15.8664 - val_loss: 63.7105 - val_mean_absolute_percentage_error: 63.7105
# Epoch 52/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 18.1815 - mean_absolute_percentage_error: 18.1815 - val_loss: 58.0995 - val_mean_absolute_percentage_error: 58.0995
# Epoch 53/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 17.9011 - mean_absolute_percentage_error: 17.9011 - val_loss: 62.8891 - val_mean_absolute_percentage_error: 62.8891
# Epoch 54/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 19.7324 - mean_absolute_percentage_error: 19.7324 - val_loss: 60.3523 - val_mean_absolute_percentage_error: 60.3523
# Epoch 55/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 19.5995 - mean_absolute_percentage_error: 19.5995 - val_loss: 64.5958 - val_mean_absolute_percentage_error: 64.5958
# Epoch 56/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 17.7495 - mean_absolute_percentage_error: 17.7495 - val_loss: 61.3855 - val_mean_absolute_percentage_error: 61.3855
# Epoch 57/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 17.0057 - mean_absolute_percentage_error: 17.0057 - val_loss: 61.9593 - val_mean_absolute_percentage_error: 61.9593
# Epoch 58/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 16.7771 - mean_absolute_percentage_error: 16.7771 - val_loss: 66.5850 - val_mean_absolute_percentage_error: 66.5850
# Epoch 59/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 16.8102 - mean_absolute_percentage_error: 16.8102 - val_loss: 63.9501 - val_mean_absolute_percentage_error: 63.9501
# Epoch 60/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 17.6687 - mean_absolute_percentage_error: 17.6687 - val_loss: 60.4614 - val_mean_absolute_percentage_error: 60.4614
# Epoch 61/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 16.3375 - mean_absolute_percentage_error: 16.3375 - val_loss: 65.2684 - val_mean_absolute_percentage_error: 65.2684
# Epoch 62/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 17.9737 - mean_absolute_percentage_error: 17.9737 - val_loss: 63.1866 - val_mean_absolute_percentage_error: 63.1866
# Epoch 63/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 15.0719 - mean_absolute_percentage_error: 15.0719 - val_loss: 62.2372 - val_mean_absolute_percentage_error: 62.2372
# Epoch 64/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 16.3166 - mean_absolute_percentage_error: 16.3166 - val_loss: 62.9241 - val_mean_absolute_percentage_error: 62.9241
# Epoch 65/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 14.1409 - mean_absolute_percentage_error: 14.1409 - val_loss: 59.3926 - val_mean_absolute_percentage_error: 59.3926
# Epoch 66/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 13.7199 - mean_absolute_percentage_error: 13.7199 - val_loss: 59.7190 - val_mean_absolute_percentage_error: 59.7190
# Epoch 67/100
# ...
# Epoch 11/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 45.0994 - mean_absolute_percentage_error: 45.0994 - val_loss: 55.3172 - val_mean_absolute_percentage_error: 55.3172
# Epoch 12/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 42.7178 - mean_absolute_percentage_error: 42.7178 - val_loss: 53.8097 - val_mean_absolute_percentage_error: 53.8097
# Epoch 13/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 43.1687 - mean_absolute_percentage_error: 43.1687 - val_loss: 55.9999 - val_mean_absolute_percentage_error: 55.9999
# Epoch 14/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 40.0036 - mean_absolute_percentage_error: 40.0036 - val_loss: 54.7008 - val_mean_absolute_percentage_error: 54.7008
# Epoch 15/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 36.4737 - mean_absolute_percentage_error: 36.4737 - val_loss: 54.9500 - val_mean_absolute_percentage_error: 54.9500
# Epoch 16/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 37.5949 - mean_absolute_percentage_error: 37.5949 - val_loss: 56.4797 - val_mean_absolute_percentage_error: 56.4797
# Epoch 17/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 40.6624 - mean_absolute_percentage_error: 40.6624 - val_loss: 58.4644 - val_mean_absolute_percentage_error: 58.4644
# Epoch 18/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 34.7449 - mean_absolute_percentage_error: 34.7449 - val_loss: 57.2100 - val_mean_absolute_percentage_error: 57.2100
# Epoch 19/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 35.4305 - mean_absolute_percentage_error: 35.4305 - val_loss: 64.6579 - val_mean_absolute_percentage_error: 64.6579
# Epoch 20/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 35.0140 - mean_absolute_percentage_error: 35.0140 - val_loss: 64.1189 - val_mean_absolute_percentage_error: 64.1189
# Epoch 21/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 31.4045 - mean_absolute_percentage_error: 31.4045 - val_loss: 58.8790 - val_mean_absolute_percentage_error: 58.8790
# Epoch 22/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 30.9507 - mean_absolute_percentage_error: 30.9507 - val_loss: 65.0875 - val_mean_absolute_percentage_error: 65.0875
# Epoch 23/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 27.5857 - mean_absolute_percentage_error: 27.5857 - val_loss: 63.3893 - val_mean_absolute_percentage_error: 63.3893
# Epoch 24/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 26.8999 - mean_absolute_percentage_error: 26.8999 - val_loss: 61.6615 - val_mean_absolute_percentage_error: 61.6615
# Epoch 25/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 27.0597 - mean_absolute_percentage_error: 27.0597 - val_loss: 59.4060 - val_mean_absolute_percentage_error: 59.4060
# Epoch 26/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 28.8186 - mean_absolute_percentage_error: 28.8186 - val_loss: 62.9103 - val_mean_absolute_percentage_error: 62.9103
# Epoch 27/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 23.1104 - mean_absolute_percentage_error: 23.1104 - val_loss: 62.2931 - val_mean_absolute_percentage_error: 62.2931
# Epoch 28/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 21.2724 - mean_absolute_percentage_error: 21.2724 - val_loss: 63.9242 - val_mean_absolute_percentage_error: 63.9242
# Epoch 29/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 24.2679 - mean_absolute_percentage_error: 24.2679 - val_loss: 61.5549 - val_mean_absolute_percentage_error: 61.5549
# Epoch 30/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 23.5468 - mean_absolute_percentage_error: 23.5468 - val_loss: 66.1419 - val_mean_absolute_percentage_error: 66.1419
# Epoch 31/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 20.2873 - mean_absolute_percentage_error: 20.2873 - val_loss: 61.7558 - val_mean_absolute_percentage_error: 61.7558
# Epoch 32/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 21.0181 - mean_absolute_percentage_error: 21.0181 - val_loss: 63.1352 - val_mean_absolute_percentage_error: 63.1352
# Epoch 33/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 20.2647 - mean_absolute_percentage_error: 20.2647 - val_loss: 64.6613 - val_mean_absolute_percentage_error: 64.6613
# Epoch 34/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 20.7816 - mean_absolute_percentage_error: 20.7816 - val_loss: 63.9910 - val_mean_absolute_percentage_error: 63.9910
# Epoch 35/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 20.1889 - mean_absolute_percentage_error: 20.1889 - val_loss: 64.2157 - val_mean_absolute_percentage_error: 64.2157
# Epoch 36/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 18.1028 - mean_absolute_percentage_error: 18.1028 - val_loss: 60.4377 - val_mean_absolute_percentage_error: 60.4377
# Epoch 37/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 20.1147 - mean_absolute_percentage_error: 20.1147 - val_loss: 63.1333 - val_mean_absolute_percentage_error: 63.1333
# Epoch 38/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 18.3951 - mean_absolute_percentage_error: 18.3951 - val_loss: 65.3274 - val_mean_absolute_percentage_error: 65.3274
# Epoch 39/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 19.3106 - mean_absolute_percentage_error: 19.3106 - val_loss: 64.2199 - val_mean_absolute_percentage_error: 64.2199
# Epoch 40/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 16.3132 - mean_absolute_percentage_error: 16.3132 - val_loss: 60.9575 - val_mean_absolute_percentage_error: 60.9575
# Epoch 41/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 16.8374 - mean_absolute_percentage_error: 16.8374 - val_loss: 63.9943 - val_mean_absolute_percentage_error: 63.9943
# Epoch 42/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 17.5757 - mean_absolute_percentage_error: 17.5757 - val_loss: 61.1793 - val_mean_absolute_percentage_error: 61.1793
# Epoch 43/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 19.4113 - mean_absolute_percentage_error: 19.4113 - val_loss: 61.7011 - val_mean_absolute_percentage_error: 61.7011
# Epoch 44/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 16.6792 - mean_absolute_percentage_error: 16.6792 - val_loss: 64.4950 - val_mean_absolute_percentage_error: 64.4950
# Epoch 45/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 15.5522 - mean_absolute_percentage_error: 15.5522 - val_loss: 58.8049 - val_mean_absolute_percentage_error: 58.8049
# Epoch 46/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 17.6198 - mean_absolute_percentage_error: 17.6198 - val_loss: 62.7584 - val_mean_absolute_percentage_error: 62.7584
# Epoch 47/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 16.7603 - mean_absolute_percentage_error: 16.7603 - val_loss: 63.3491 - val_mean_absolute_percentage_error: 63.3491
# Epoch 48/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 18.8973 - mean_absolute_percentage_error: 18.8973 - val_loss: 60.7913 - val_mean_absolute_percentage_error: 60.7913
# Epoch 49/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 16.1863 - mean_absolute_percentage_error: 16.1863 - val_loss: 62.4082 - val_mean_absolute_percentage_error: 62.4082
# Epoch 50/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 15.5233 - mean_absolute_percentage_error: 15.5233 - val_loss: 64.1024 - val_mean_absolute_percentage_error: 64.1024
# Epoch 51/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 16.5999 - mean_absolute_percentage_error: 16.5999 - val_loss: 65.6077 - val_mean_absolute_percentage_error: 65.6077
# Epoch 52/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 15.0786 - mean_absolute_percentage_error: 15.0786 - val_loss: 58.9528 - val_mean_absolute_percentage_error: 58.9528
# Epoch 53/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 18.0603 - mean_absolute_percentage_error: 18.0603 - val_loss: 66.1894 - val_mean_absolute_percentage_error: 66.1894
# Epoch 54/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 17.0592 - mean_absolute_percentage_error: 17.0592 - val_loss: 64.8083 - val_mean_absolute_percentage_error: 64.8083
# Epoch 55/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 15.4933 - mean_absolute_percentage_error: 15.4933 - val_loss: 60.9584 - val_mean_absolute_percentage_error: 60.9584
# Epoch 56/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 16.6345 - mean_absolute_percentage_error: 16.6345 - val_loss: 61.5838 - val_mean_absolute_percentage_error: 61.5838
# Epoch 57/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 15.4674 - mean_absolute_percentage_error: 15.4674 - val_loss: 67.1125 - val_mean_absolute_percentage_error: 67.1125
# Epoch 58/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 15.5429 - mean_absolute_percentage_error: 15.5429 - val_loss: 61.7566 - val_mean_absolute_percentage_error: 61.7566
# Epoch 59/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 13.4933 - mean_absolute_percentage_error: 13.4933 - val_loss: 62.5691 - val_mean_absolute_percentage_error: 62.5691
# Epoch 60/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 14.5730 - mean_absolute_percentage_error: 14.5730 - val_loss: 65.9567 - val_mean_absolute_percentage_error: 65.9567
# Epoch 61/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 14.8475 - mean_absolute_percentage_error: 14.8475 - val_loss: 57.8056 - val_mean_absolute_percentage_error: 57.8056
# Epoch 62/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 14.2675 - mean_absolute_percentage_error: 14.2675 - val_loss: 63.3936 - val_mean_absolute_percentage_error: 63.3936
# Epoch 63/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 12.7900 - mean_absolute_percentage_error: 12.7900 - val_loss: 63.2200 - val_mean_absolute_percentage_error: 63.2200
# Epoch 64/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 13.8549 - mean_absolute_percentage_error: 13.8549 - val_loss: 59.6116 - val_mean_absolute_percentage_error: 59.6116
# Epoch 65/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 14.5397 - mean_absolute_percentage_error: 14.5397 - val_loss: 60.1050 - val_mean_absolute_percentage_error: 60.1050
# Epoch 66/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 13.5874 - mean_absolute_percentage_error: 13.5874 - val_loss: 67.9028 - val_mean_absolute_percentage_error: 67.9028
# Epoch 67/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 13.1073 - mean_absolute_percentage_error: 13.1073 - val_loss: 59.4619 - val_mean_absolute_percentage_error: 59.4619
# Epoch 68/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 12.1754 - mean_absolute_percentage_error: 12.1754 - val_loss: 67.5025 - val_mean_absolute_percentage_error: 67.5025
# Epoch 69/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 14.0348 - mean_absolute_percentage_error: 14.0348 - val_loss: 62.0845 - val_mean_absolute_percentage_error: 62.0845
# Epoch 70/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 15.3709 - mean_absolute_percentage_error: 15.3709 - val_loss: 63.9411 - val_mean_absolute_percentage_error: 63.9411
# Epoch 71/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 12.1817 - mean_absolute_percentage_error: 12.1817 - val_loss: 63.3254 - val_mean_absolute_percentage_error: 63.3254
# Epoch 72/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 10.5783 - mean_absolute_percentage_error: 10.5783 - val_loss: 65.7350 - val_mean_absolute_percentage_error: 65.7350
# Epoch 73/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 11.4631 - mean_absolute_percentage_error: 11.4631 - val_loss: 59.7596 - val_mean_absolute_percentage_error: 59.7596
# Epoch 74/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 12.6861 - mean_absolute_percentage_error: 12.6861 - val_loss: 67.1343 - val_mean_absolute_percentage_error: 67.1343
# Epoch 75/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 12.4050 - mean_absolute_percentage_error: 12.4050 - val_loss: 62.4445 - val_mean_absolute_percentage_error: 62.4445
# Epoch 76/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 13.6834 - mean_absolute_percentage_error: 13.6834 - val_loss: 62.8139 - val_mean_absolute_percentage_error: 62.8139
# Epoch 77/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 10.7197 - mean_absolute_percentage_error: 10.7197 - val_loss: 60.2561 - val_mean_absolute_percentage_error: 60.2561
# Epoch 78/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 13.2081 - mean_absolute_percentage_error: 13.2081 - val_loss: 64.7868 - val_mean_absolute_percentage_error: 64.7868
# Epoch 79/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 11.7344 - mean_absolute_percentage_error: 11.7344 - val_loss: 62.3279 - val_mean_absolute_percentage_error: 62.3279
# Epoch 80/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 11.5823 - mean_absolute_percentage_error: 11.5823 - val_loss: 60.2953 - val_mean_absolute_percentage_error: 60.2953
# Epoch 81/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 13.6735 - mean_absolute_percentage_error: 13.6735 - val_loss: 67.6148 - val_mean_absolute_percentage_error: 67.6148
# Epoch 82/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 13.5669 - mean_absolute_percentage_error: 13.5669 - val_loss: 61.6212 - val_mean_absolute_percentage_error: 61.6212
# Epoch 83/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 12.3135 - mean_absolute_percentage_error: 12.3135 - val_loss: 65.3529 - val_mean_absolute_percentage_error: 65.3529
# Epoch 84/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 12.1637 - mean_absolute_percentage_error: 12.1637 - val_loss: 63.8806 - val_mean_absolute_percentage_error: 63.8806
# Epoch 85/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 11.2829 - mean_absolute_percentage_error: 11.2829 - val_loss: 59.9614 - val_mean_absolute_percentage_error: 59.9614
# Epoch 86/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.3919 - mean_absolute_percentage_error: 9.3919 - val_loss: 64.3640 - val_mean_absolute_percentage_error: 64.3640
# Epoch 87/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 10.5908 - mean_absolute_percentage_error: 10.5908 - val_loss: 66.0046 - val_mean_absolute_percentage_error: 66.0046
# Epoch 88/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 10.3935 - mean_absolute_percentage_error: 10.3935 - val_loss: 58.4580 - val_mean_absolute_percentage_error: 58.4580
# Epoch 89/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 13.2124 - mean_absolute_percentage_error: 13.2124 - val_loss: 63.0788 - val_mean_absolute_percentage_error: 63.0788
# Epoch 90/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 11.1873 - mean_absolute_percentage_error: 11.1873 - val_loss: 64.9542 - val_mean_absolute_percentage_error: 64.9542
# Epoch 91/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 10.6982 - mean_absolute_percentage_error: 10.6982 - val_loss: 62.2295 - val_mean_absolute_percentage_error: 62.2295
# Epoch 92/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 10.0949 - mean_absolute_percentage_error: 10.0949 - val_loss: 64.7063 - val_mean_absolute_percentage_error: 64.7063
# Epoch 93/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 10.0170 - mean_absolute_percentage_error: 10.0170 - val_loss: 63.1290 - val_mean_absolute_percentage_error: 63.1290
# Epoch 94/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 10.2120 - mean_absolute_percentage_error: 10.2120 - val_loss: 63.2223 - val_mean_absolute_percentage_error: 63.2223
# Epoch 95/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 10.3894 - mean_absolute_percentage_error: 10.3894 - val_loss: 62.1555 - val_mean_absolute_percentage_error: 62.1555
# Epoch 96/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 10.5559 - mean_absolute_percentage_error: 10.5559 - val_loss: 61.5041 - val_mean_absolute_percentage_error: 61.5041
# Epoch 97/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 10.5292 - mean_absolute_percentage_error: 10.5292 - val_loss: 60.8550 - val_mean_absolute_percentage_error: 60.8550
# Epoch 98/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.8567 - mean_absolute_percentage_error: 9.8567 - val_loss: 60.6791 - val_mean_absolute_percentage_error: 60.6791
# Epoch 99/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 10.8096 - mean_absolute_percentage_error: 10.8096 - val_loss: 66.4274 - val_mean_absolute_percentage_error: 66.4274
# Epoch 100/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 12.0758 - mean_absolute_percentage_error: 12.0758 - val_loss: 63.9623 - val_mean_absolute_percentage_error: 63.9623
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# Predicting house prices - Estimation Error: 63.96%
# AvgPooling - Train Loss: 12.4384, Validation Loss: 63.9623

# %%
# Report results for other house sections
house_sections = ['kitchen', 'bedroom', 'bathroom']
section_results = []

for section in house_sections:
    print(f"Evaluating {section} images...")
    # Assume data loading and preprocessing for each section
    section_images = ...  # Replace with actual data loading logic
    section_labels = ...  # Replace with actual data loading logic

    section_images /= 255.0  # Normalize images
    section_labels /= max_price  # Normalize labels

    section_X_train, section_X_val, section_Y_train, section_Y_val = train_test_split(
        section_images, section_labels, test_size=0.2, random_state=seed
    )
    prices_predicted = model.predict(X_val).flatten()
    diff = ((prices_predicted - Y_val) / Y_val) * 100
    error_mean = np.mean(np.abs(diff))

    print("Predicting house prices - Estimation Error: {:.2f}%".format(error_mean))
    model = proposed_model['model']
    val_loss = model.evaluate(section_X_val, section_Y_val, verbose=0)[0]
    section_results.append({
        'section': section,
        'val_loss': val_loss
    })

# Display results in a table
section_df = pd.DataFrame(section_results)
print("\nValidation Results for Other House Sections:")
print(section_df)

plt.figure(figsize=(10, 6))
plt.bar(section_df['section'], section_df['val_loss'], color='skyblue')
plt.xlabel('House Sections')
plt.ylabel('Validation Loss (Mean Absolute Percentage Error)')
plt.title('Validation Loss Across Different House Sections')
plt.tight_layout()
plt.show()

# %% [markdown]
# The metric used in this problem to evaluate the performance is the same we used for training the model, the mean absolute percentage error. Mean absolute percentage error is defined as $\frac{100}{n} \sum_n \frac{|\hat{y} - y|}{|y|}$ where $y$ is the ground-truth, $\hat{y}$ is the estimation of the model and `n` the number of elements in the set we are evaluating.

# %%
prices_predicted = model.predict(X_val).flatten()
diff = ((prices_predicted - Y_val) / Y_val) * 100
error_mean = np.mean(np.abs(diff))

print("Predicting house prices - Estimation Error: {:.2f}%".format(error_mean))

# %% [markdown]
# **Report**:
#
#
# *   Propose a CNN architecture that has an estimation error in the validation set below 75%.
# *   Present a figure showing the training and validation loss vs the number of training epochs for different architectural design choices. Discuss the gap between the training and validation loss depending on the proposed architecture.
# *   Report a table with results when using any of the other images from the house (kitchen, bedroom, and bathroom).
